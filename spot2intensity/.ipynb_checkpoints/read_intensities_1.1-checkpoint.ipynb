# %%
from spot2intensity import Point, Rectangle, Grid, plot_patches,create_patches,create_circle_patches, rectangle_reshape
import matplotlib.pyplot as plt
import cv2
import copy
import numpy as np

# %%
select_collection = "180124_N22_Cal"

# %%
directory = ["180124_N21_Pan","180124_E14_X31","180124_N22_Cal","180124_N23_X31","180124_E15_X31"]

images_paths = ["180124_N21_Pan.gif",
                '180124_E14_X31_Allantois_100_600_635_635_2_635.gif',
                '180124_N22_Cal_100_600_635_635_635.gif',
                '180124_N23_X31_100_600_635_635_635_635.gif',
                '180124_E15_X31_100_600_635_635.gif',
               ]
images_paths_jpg  = [im_path.replace('.gif','.jpg') for im_path in images_paths]
fpath_dict = dict(zip(directory,images_paths_jpg))
fpath_dict = {key:'data/'+key+'/'+value for key,value in fpath_dict.iteritems()}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-6f86cabe5b95> in <module>()
#       9 images_paths_jpg  = [im_path.replace('.gif','.jpg') for im_path in images_paths]
#      10 fpath_dict = dict(zip(directory,images_paths_jpg))
# ---> 11 fpath_dict = {key:'data/'+key+'/'+value for key,value in fpath_dict.iteritems()}
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
#################################
rec_N23_1 = [(336, 321),
            (354, 1831),
            (1959, 1853),
            (1968, 312),
            ]

rec_N23_2 = [(328, 2858),
            (332, 4385),
            (1946, 4403),
            (1960, 2873),
            ]

rec_N23_3 = [(321, 5251),
            (310, 6763),
            (1929, 6789),
            (1941, 5255),
            ]
##############################
rec_N22_1 = [(310, 314),
            (323, 1846),
            (1928, 1831),
            (1931, 304),
           ]

rec_N22_2 = [(321, 2873),
            (337, 4399),
            (1951, 4382),
            (1926, 2869),
           ]
rec_N22_3 = [(311, 5254),
            (349, 6768),
            (1944, 6766),
            (1959, 5239),
                       ]
#############################
rec_N21_1 = [(296, 244),
           (314, 1746),
           (1903, 1766),
           (1912, 207),
            ]

rec_N21_2 = [(303, 2791),
             (298, 4303),
             (1922, 4293),
             (1908, 2786),
            ]

rec_N21_3 = [(302, 5164),
             (297, 6680),
             (1923, 6701),
             (1910, 5158),
            ]

# %%
def find_circle_coordinates(image,x0,y0):
    pic=copy.deepcopy(image)
    pic[pic > 120] = 0
    pic[pic < 1] = 0
    edges = feature.canny(pic,sigma=0.5)
 
    # Detect two radii
    hough_radii = np.arange(40, 80, 2)

    hough_res = hough_circle(edges, hough_radii)

    # Select the most prominent  circle:
    accums, cx, cy, radii = hough_circle_peaks(hough_res, hough_radii,min_xdistance = hough_radii.min() , min_ydistance = hough_radii.min(),
                                               total_num_peaks=1)
    
    return cy[0]+y0, cx[0]+x0,radii[0], accums[0]

# %%
from skimage import feature
from skimage import  color
from skimage.transform import hough_circle, hough_circle_peaks
#from skimage.draw import circle_perimeter, ellipse_perimeter

# %%
select_collection = "180124_N23_X31"

rect1 = Rectangle(*tuple(Point(x,y) for x,y in rec_N23_1))
rect2 = Rectangle(*tuple(Point(x,y) for x,y in rec_N23_2))
rect3 = Rectangle(*tuple(Point(x,y) for x,y in rec_N23_3))
shape = Point(10,10)
grid1 = Grid(rectangle = rect1, shape = shape)
grid2 = Grid(rectangle = rect2, shape = copy.deepcopy(shape))
grid3 = Grid(rectangle = rect3, shape = copy.deepcopy(shape))

imag = cv2.imread(fpath_dict[select_collection],0)


fig,ax = plt.subplots(1, figsize=(30,30))
ax.imshow(imag,cmap=plt.cm.gray)

intensities = []
intensities2 = []

spot_images = []
circles = []
circle_qual = []
xy = []
grid4 = copy.deepcopy(grid3)
grid4.add_row(where="top")
grid4.add_row(where="bottom")

for grid in [grid1,grid2,grid3]:
    grid.add_row(where="top")
    grid.add_row(where="bottom")
    for x,y in grid.points:
        delta_x = int(grid.abs_horizontal_spacing)
        delta_y = int(grid.abs_vertical_spacing)
        x = int(x)
        y = int(y)
        xy.append((x,y))
        rec = create_patches((x,y),delta_x,delta_y)
        ax.add_patch(rec)
        x0,y0 = rec.xy
        
        x0 = int(x0)
        y0 = int(y0)
        if x0 < 0:
            x0 = 0
        if y0 < 0:
            y0 = 0
        
        
        spot_imag= imag[y0:y0+delta_x ,x0:x0+delta_x]
        spot_images.append(spot_imag)
        intensities.append(spot_imag.sum())
        #circx,circy,radius, accums = find_circle_coordinates(spot_imag,0,0)
        #circle_qual.append(accums)
        
        
        #circ = create_circle_patches((circy,circx),radius)
        #ax.add_patch(circ)
        #intensity2 = np.mean([value for index,value in np.ndenumerate(spot_imag) if circ.contains_point(index)])   
        #intensities.append(intensity2)
        #circle_qual.append(accums)
        print(x,y)
        
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-5be7dbb90897> in <module>()
#      13
#      14 fig,ax = plt.subplots(1, figsize=(30,30))
# ---> 15 ax.imshow(imag,cmap=plt.cm.gray)
#      16
#      17 intensities = []
#
# ~/Envs/flutype_webapp/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~/Envs/flutype_webapp/lib/python3.5/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5125                               resample=resample, **kwargs)
#    5126
# -> 5127         im.set_data(X)
#    5128         im.set_alpha(alpha)
#    5129         if im.get_clip_path() is None:
#
# ~/Envs/flutype_webapp/lib/python3.5/site-packages/matplotlib/image.py in set_data(self, A)
#     605         if (self._A.dtype != np.uint8 and
#     606                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 607             raise TypeError("Image data cannot be converted to float")
#     608
#     609         if not (self._A.ndim == 2
#
# TypeError: Image data cannot be converted to float

# %%
print(circle_qual)
plt.hist(np.array(circle_qual),60)
plt.show()
# Out:
# []

# %%
pic = spot_images[11]
circy,circx,radius,qual = find_circle_coordinates(pic,0,0)
circ = create_circle_patches((circx,circy),radius)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-09fb409c4b56> in <module>()
#       2 pic = spot_images[11]
#       3 circy,circx,radius,qual = find_circle_coordinates(pic,0,0)
# ----> 4 circ = create_circle_patches((circx,circy),radius)
#
# /home/janekg89/Develop/Pycharm_Projects/flutype_analyse_wepdata/spot2intensity/spot2intensity.py in create_circle_patches(center, radius)
#     159         fill=False,  # remove background
#     160         linewidth=1,
# --> 161         edgecolor='r',
#     162     )
#     163
#
# TypeError: __init__() takes at least 2 arguments (2 given)

# %%
ix = np.ndindex(pic.shape)
circ.contains_point(ix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-7f299355aa90> in <module>()
#       1 ix = np.ndindex(pic.shape)
# ----> 2 circ.contains_point(ix)
#
# /home/janekg89/Envs/flutype_webapp/local/lib/python2.7/site-packages/matplotlib/patches.pyc in contains_point(self, point, radius)
#     188         return self.get_path().contains_point(point,
#     189                                               self.get_transform(),
# --> 190                                               radius)
#     191
#     192     def update_from(self, other):
#
# /home/janekg89/Envs/flutype_webapp/local/lib/python2.7/site-packages/matplotlib/path.pyc in contains_point(self, point, transform, radius)
#     497             self = transform.transform_path(self)
#     498             transform = None
# --> 499         return _path.point_in_path(point[0], point[1], radius, self, transform)
#     500
#     501     def contains_points(self, points, transform=None, radius=0.0):
#
# TypeError: 'ndindex' object does not support indexing

# %%
import timeit

np.mean([value for index,value in np.ndenumerate(pic) if circ.contains_point(index)])
# Out:
# 31.385862859157413

# %%
import timeit
pic = spot_images[10]
fig, ax =  plt.subplots(1, figsize=(5,5))
circy, circx,radius, accums = find_circle_coordinates(pic,0,0)
print(circy, circx)
#np.mean([value for index,value in np.ndenumerate(pic) if contained_in_circle(circx,circy,radius)])
circ = create_circle_patches((75,75),radius,transform=None)
ax.imshow(pic,cmap=plt.cm.gray)
ax.add_patch(circ)
plt.show()
# Out:
# (101, 108)

# %%
def calc_intensity(pic):
    result = 0
    (Np, Nq) = pic.shape
    for p in range(Np):
        for q in range(Nq):
            # zero indexed
            value = pic[p,q]
            if ( r**2 <= (x0-p)**2 + (y0-q)**2 ):
                result += value
    return result

# %%
def contained_in_circle(x0,x,y0,y,r):
    return r**2 <= (x0-x)**2 + (y0-y)**2

# %%
k = 0
for index,value in np.ndenumerate(pic):
    print(k)
    print(index, value)
    k+=1
# Out:
# 0
# ((0, 0), 15)
# 1
# ((0, 1), 6)
# 2
# ((0, 2), 17)
# 3
# ((0, 3), 10)
# 4
# ((0, 4), 28)
# 5
# ((0, 5), 13)
# 6
# ((0, 6), 15)
# 7
# ((0, 7), 16)
# 8
# ((0, 8), 7)
# 9
# ((0, 9), 17)
# 10
# ((0, 10), 15)
# 11
# ((0, 11), 11)
# 12
# ((0, 12), 8)
# 13
# ((0, 13), 18)
# 14
# ((0, 14), 17)
# 15
# ((0, 15), 10)
# 16
# ((0, 16), 14)
# 17
# ((0, 17), 6)
# 18
# ((0, 18), 20)
# 19
# ((0, 19), 19)
# 20
# ((0, 20), 16)
# 21
# ((0, 21), 16)
# 22
# ((0, 22), 11)
# 23
# ((0, 23), 22)
# 24
# ((0, 24), 15)
# 25
# ((0, 25), 4)
# 26
# ((0, 26), 15)
# 27
# ((0, 27), 8)
# 28
# ((0, 28), 12)
# 29
# ((0, 29), 12)
# 30
# ((0, 30), 13)
# 31
# ((0, 31), 20)
# 32
# ((0, 32), 13)
# 33
# ((0, 33), 21)
# 34
# ((0, 34), 14)
# 35
# ((0, 35), 10)
# 36
# ((0, 36), 19)
# 37
# ((0, 37), 21)
# 38
# ((0, 38), 12)
# 39
# ((0, 39), 8)
# 40
# ((0, 40), 14)
# 41
# ((0, 41), 19)
# 42
# ((0, 42), 19)
# 43
# ((0, 43), 17)
# 44
# ((0, 44), 18)
# 45
# ((0, 45), 6)
# 46
# ((0, 46), 13)
# 47
# ((0, 47), 12)
# 48
# ((0, 48), 9)
# 49
# ((0, 49), 17)
# 50
# ((0, 50), 19)
# 51
# ((0, 51), 14)
# 52
# ((0, 52), 11)
# 53
# ((0, 53), 7)
# 54
# ((0, 54), 25)
# 55
# ((0, 55), 10)
# 56
# ((0, 56), 10)
# 57
# ((0, 57), 19)
# 58
# ((0, 58), 14)
# 59
# ((0, 59), 17)
# 60
# ((0, 60), 10)
# 61
# ((0, 61), 10)
# 62
# ((0, 62), 7)
# 63
# ((0, 63), 19)
# 64
# ((0, 64), 10)
# 65
# ((0, 65), 13)
# 66
# ((0, 66), 16)
# 67
# ((0, 67), 17)
# 68
# ((0, 68), 14)
# 69
# ((0, 69), 6)
# 70
# ((0, 70), 14)
# 71
# ((0, 71), 16)
# 72
# ((0, 72), 8)
# 73
# ((0, 73), 14)
# 74
# ((0, 74), 13)
# 75
# ((0, 75), 13)
# 76
# ((0, 76), 10)
# 77
# ((0, 77), 13)
# 78
# ((0, 78), 8)
# 79
# ((0, 79), 9)
# 80
# ((0, 80), 14)
# 81
# ((0, 81), 15)
# 82
# ((0, 82), 14)
# 83
# ((0, 83), 9)
# 84
# ((0, 84), 17)
# 85
# ((0, 85), 8)
# 86
# ((0, 86), 13)
# 87
# ((0, 87), 13)
# 88
# ((0, 88), 16)
# 89
# ((0, 89), 44)
# 90
# ((0, 90), 14)
# 91
# ((0, 91), 8)
# 92
# ((0, 92), 12)
# 93
# ((0, 93), 20)
# 94
# ((0, 94), 8)
# 95
# ((0, 95), 7)
# 96
# ((0, 96), 15)
# 97
# ((0, 97), 11)
# 98
# ((0, 98), 9)
# 99
# ((0, 99), 11)
# 100
# ((0, 100), 5)
# 101
# ((0, 101), 12)
# 102
# ((0, 102), 2)
# 103
# ((0, 103), 24)
# 104
# ((0, 104), 10)
# 105
# ((0, 105), 10)
# 106
# ((0, 106), 14)
# 107
# ((0, 107), 13)
# 108
# ((0, 108), 13)
# 109
# ((0, 109), 17)
# 110
# ((0, 110), 6)
# 111
# ((0, 111), 11)
# 112
# ((0, 112), 9)
# 113
# ((0, 113), 9)
# 114
# ((0, 114), 10)
# 115
# ((0, 115), 10)
# 116
# ((0, 116), 19)
# 117
# ((0, 117), 20)
# 118
# ((0, 118), 19)
# 119
# ((0, 119), 13)
# 120
# ((0, 120), 12)
# 121
# ((0, 121), 16)
# 122
# ((0, 122), 10)
# 123
# ((0, 123), 10)
# 124
# ((0, 124), 12)
# 125
# ((0, 125), 19)
# 126
# ((0, 126), 17)
# 127
# ((0, 127), 14)
# 128
# ((0, 128), 11)
# 129
# ((0, 129), 17)
# 130
# ((0, 130), 14)
# 131
# ((0, 131), 17)
# 132
# ((0, 132), 15)
# 133
# ((0, 133), 7)
# 134
# ((0, 134), 10)
# 135
# ((0, 135), 17)
# 136
# ((0, 136), 14)
# 137
# ((0, 137), 12)
# 138
# ((0, 138), 12)
# 139
# ((0, 139), 8)
# 140
# ((0, 140), 13)
# 141
# ((0, 141), 12)
# 142
# ((0, 142), 12)
# 143
# ((0, 143), 19)
# 144
# ((0, 144), 14)
# 145
# ((0, 145), 13)
# 146
# ((0, 146), 16)
# 147
# ((0, 147), 15)
# 148
# ((0, 148), 17)
# 149
# ((0, 149), 11)
# 150
# ((0, 150), 17)
# 151
# ((0, 151), 11)
# 152
# ((0, 152), 7)
# 153
# ((0, 153), 13)
# 154
# ((0, 154), 13)
# 155
# ((0, 155), 7)
# 156
# ((0, 156), 7)
# 157
# ((0, 157), 7)
# 158
# ((0, 158), 21)
# 159
# ((0, 159), 9)
# 160
# ((0, 160), 13)
# 161
# ((0, 161), 15)
# 162
# ((0, 162), 15)
# 163
# ((0, 163), 8)
# 164
# ((0, 164), 11)
# 165
# ((0, 165), 9)
# 166
# ((0, 166), 13)
# 167
# ((0, 167), 5)
# 168
# ((0, 168), 10)
# 169
# ((0, 169), 19)
# 170
# ((0, 170), 23)
# 171
# ((0, 171), 17)
# 172
# ((0, 172), 23)
# 173
# ((0, 173), 13)
# 174
# ((0, 174), 10)
# 175
# ((0, 175), 19)
# 176
# ((0, 176), 17)
# 177
# ((0, 177), 16)
# 178
# ((0, 178), 7)
# 179
# ((0, 179), 19)
# 180
# ((0, 180), 18)
# 181
# ((1, 0), 17)
# 182
# ((1, 1), 7)
# 183
# ((1, 2), 15)
# 184
# ((1, 3), 23)
# 185
# ((1, 4), 19)
# 186
# ((1, 5), 15)
# 187
# ((1, 6), 11)
# 188
# ((1, 7), 18)
# 189
# ((1, 8), 15)
# 190
# ((1, 9), 14)
# 191
# ((1, 10), 10)
# 192
# ((1, 11), 8)
# 193
# ((1, 12), 13)
# 194
# ((1, 13), 13)
# 195
# ((1, 14), 8)
# 196
# ((1, 15), 8)
# 197
# ((1, 16), 12)
# 198
# ((1, 17), 8)
# 199
# ((1, 18), 11)
# 200
# ((1, 19), 12)
# 201
# ((1, 20), 9)
# 202
# ((1, 21), 12)
# 203
# ((1, 22), 13)
# 204
# ((1, 23), 11)
# 205
# ((1, 24), 19)
# 206
# ((1, 25), 9)
# 207
# ((1, 26), 13)
# 208
# ((1, 27), 17)
# 209
# ((1, 28), 15)
# 210
# ((1, 29), 17)
# 211
# ((1, 30), 19)
# 212
# ((1, 31), 8)
# 213
# ((1, 32), 10)
# 214
# ((1, 33), 19)
# 215
# ((1, 34), 18)
# 216
# ((1, 35), 10)
# 217
# ((1, 36), 11)
# 218
# ((1, 37), 16)
# 219
# ((1, 38), 10)
# 220
# ((1, 39), 15)
# 221
# ((1, 40), 10)
# 222
# ((1, 41), 20)
# 223
# ((1, 42), 21)
# 224
# ((1, 43), 22)
# 225
# ((1, 44), 27)
# 226
# ((1, 45), 10)
# 227
# ((1, 46), 11)
# 228
# ((1, 47), 13)
# 229
# ((1, 48), 7)
# 230
# ((1, 49), 13)
# 231
# ((1, 50), 11)
# 232
# ((1, 51), 11)
# 233
# ((1, 52), 11)
# 234
# ((1, 53), 7)
# 235
# ((1, 54), 8)
# 236
# ((1, 55), 12)
# 237
# ((1, 56), 13)
# 238
# ((1, 57), 14)
# 239
# ((1, 58), 12)
# 240
# ((1, 59), 6)
# 241
# ((1, 60), 12)
# 242
# ((1, 61), 15)
# 243
# ((1, 62), 25)
# 244
# ((1, 63), 11)
# 245
# ((1, 64), 13)
# 246
# ((1, 65), 9)
# 247
# ((1, 66), 9)
# 248
# ((1, 67), 8)
# 249
# ((1, 68), 6)
# 250
# ((1, 69), 13)
# 251
# ((1, 70), 14)
# 252
# ((1, 71), 16)
# 253
# ((1, 72), 8)
# 254
# ((1, 73), 9)
# 255
# ((1, 74), 21)
# 256
# ((1, 75), 14)
# 257
# ((1, 76), 13)
# 258
# ((1, 77), 13)
# 259
# ((1, 78), 14)
# 260
# ((1, 79), 11)
# 261
# ((1, 80), 7)
# 262
# ((1, 81), 14)
# 263
# ((1, 82), 11)
# 264
# ((1, 83), 8)
# 265
# ((1, 84), 12)
# 266
# ((1, 85), 3)
# 267
# ((1, 86), 16)
# 268
# ((1, 87), 13)
# 269
# ((1, 88), 10)
# 270
# ((1, 89), 22)
# 271
# ((1, 90), 12)
# 272
# ((1, 91), 19)
# 273
# ((1, 92), 11)
# 274
# ((1, 93), 8)
# 275
# ((1, 94), 12)
# 276
# ((1, 95), 8)
# 277
# ((1, 96), 11)
# 278
# ((1, 97), 9)
# 279
# ((1, 98), 26)
# 280
# ((1, 99), 19)
# 281
# ((1, 100), 15)
# 282
# ((1, 101), 19)
# 283
# ((1, 102), 14)
# 284
# ((1, 103), 8)
# 285
# ((1, 104), 18)
# 286
# ((1, 105), 15)
# 287
# ((1, 106), 7)
# 288
# ((1, 107), 16)
# 289
# ((1, 108), 12)
# 290
# ((1, 109), 18)
# 291
# ((1, 110), 9)
# 292
# ((1, 111), 11)
# 293
# ((1, 112), 16)
# 294
# ((1, 113), 13)
# 295
# ((1, 114), 19)
# 296
# ((1, 115), 18)
# 297
# ((1, 116), 9)
# 298
# ((1, 117), 8)
# 299
# ((1, 118), 15)
# 300
# ((1, 119), 12)
# 301
# ((1, 120), 19)
# 302
# ((1, 121), 11)
# 303
# ((1, 122), 13)
# 304
# ((1, 123), 10)
# 305
# ((1, 124), 13)
# 306
# ((1, 125), 13)
# 307
# ((1, 126), 19)
# 308
# ((1, 127), 11)
# 309
# ((1, 128), 18)
# 310
# ((1, 129), 18)
# 311
# ((1, 130), 5)
# 312
# ((1, 131), 12)
# 313
# ((1, 132), 30)
# 314
# ((1, 133), 15)
# 315
# ((1, 134), 13)
# 316
# ((1, 135), 18)
# 317
# ((1, 136), 11)
# 318
# ((1, 137), 12)
# 319
# ((1, 138), 13)
# 320
# ((1, 139), 6)
# 321
# ((1, 140), 17)
# 322
# ((1, 141), 5)
# 323
# ((1, 142), 13)
# 324
# ((1, 143), 13)
# 325
# ((1, 144), 9)
# 326
# ((1, 145), 15)
# 327
# ((1, 146), 17)
# 328
# ((1, 147), 13)
# 329
# ((1, 148), 9)
# 330
# ((1, 149), 11)
# 331
# ((1, 150), 9)
# 332
# ((1, 151), 9)
# 333
# ((1, 152), 17)
# 334
# ((1, 153), 32)
# 335
# ((1, 154), 12)
# 336
# ((1, 155), 8)
# 337
# ((1, 156), 7)
# 338
# ((1, 157), 19)
# 339
# ((1, 158), 9)
# 340
# ((1, 159), 7)
# 341
# ((1, 160), 15)
# 342
# ((1, 161), 11)
# 343
# ((1, 162), 15)
# 344
# ((1, 163), 16)
# 345
# ((1, 164), 16)
# 346
# ((1, 165), 10)
# 347
# ((1, 166), 10)
# 348
# ((1, 167), 14)
# 349
# ((1, 168), 10)
# 350
# ((1, 169), 12)
# 351
# ((1, 170), 13)
# 352
# ((1, 171), 18)
# 353
# ((1, 172), 10)
# 354
# ((1, 173), 20)
# 355
# ((1, 174), 13)
# 356
# ((1, 175), 17)
# 357
# ((1, 176), 14)
# 358
# ((1, 177), 11)
# 359
# ((1, 178), 10)
# 360
# ((1, 179), 10)
# 361
# ((1, 180), 28)
# 362
# ((2, 0), 9)
# 363
# ((2, 1), 10)
# 364
# ((2, 2), 17)
# 365
# ((2, 3), 10)
# 366
# ((2, 4), 11)
# 367
# ((2, 5), 9)
# 368
# ((2, 6), 7)
# 369
# ((2, 7), 13)
# 370
# ((2, 8), 10)
# 371
# ((2, 9), 16)
# 372
# ((2, 10), 17)
# 373
# ((2, 11), 20)
# 374
# ((2, 12), 13)
# 375
# ((2, 13), 1)
# 376
# ((2, 14), 9)
# 377
# ((2, 15), 11)
# 378
# ((2, 16), 13)
# 379
# ((2, 17), 19)
# 380
# ((2, 18), 19)
# 381
# ((2, 19), 28)
# 382
# ((2, 20), 8)
# 383
# ((2, 21), 16)
# 384
# ((2, 22), 13)
# 385
# ((2, 23), 17)
# 386
# ((2, 24), 16)
# 387
# ((2, 25), 13)
# 388
# ((2, 26), 15)
# 389
# ((2, 27), 9)
# 390
# ((2, 28), 11)
# 391
# ((2, 29), 9)
# 392
# ((2, 30), 8)
# 393
# ((2, 31), 19)
# 394
# ((2, 32), 14)
# 395
# ((2, 33), 10)
# 396
# ((2, 34), 11)
# 397
# ((2, 35), 12)
# 398
# ((2, 36), 10)
# 399
# ((2, 37), 5)
# 400
# ((2, 38), 11)
# 401
# ((2, 39), 12)
# 402
# ((2, 40), 8)
# 403
# ((2, 41), 13)
# 404
# ((2, 42), 12)
# 405
# ((2, 43), 15)
# 406
# ((2, 44), 13)
# 407
# ((2, 45), 18)
# 408
# ((2, 46), 16)
# 409
# ((2, 47), 6)
# 410
# ((2, 48), 15)
# 411
# ((2, 49), 10)
# 412
# ((2, 50), 11)
# 413
# ((2, 51), 11)
# 414
# ((2, 52), 14)
# 415
# ((2, 53), 16)
# 416
# ((2, 54), 14)
# 417
# ((2, 55), 12)
# 418
# ((2, 56), 16)
# 419
# ((2, 57), 11)
# 420
# ((2, 58), 19)
# 421
# ((2, 59), 10)
# 422
# ((2, 60), 9)
# 423
# ((2, 61), 15)
# 424
# ((2, 62), 13)
# 425
# ((2, 63), 9)
# 426
# ((2, 64), 11)
# 427
# ((2, 65), 12)
# 428
# ((2, 66), 15)
# 429
# ((2, 67), 22)
# 430
# ((2, 68), 7)
# 431
# ((2, 69), 21)
# 432
# ((2, 70), 6)
# 433
# ((2, 71), 8)
# 434
# ((2, 72), 19)
# 435
# ((2, 73), 13)
# 436
# ((2, 74), 7)
# 437
# ((2, 75), 7)
# 438
# ((2, 76), 13)
# 439
# ((2, 77), 13)
# 440
# ((2, 78), 8)
# 441
# ((2, 79), 12)
# 442
# ((2, 80), 12)
# 443
# ((2, 81), 19)
# 444
# ((2, 82), 10)
# 445
# ((2, 83), 12)
# 446
# ((2, 84), 16)
# 447
# ((2, 85), 10)
# 448
# ((2, 86), 17)
# 449
# ((2, 87), 11)
# 450
# ((2, 88), 20)
# 451
# ((2, 89), 19)
# 452
# ((2, 90), 16)
# 453
# ((2, 91), 22)
# 454
# ((2, 92), 16)
# 455
# ((2, 93), 6)
# 456
# ((2, 94), 5)
# 457
# ((2, 95), 12)
# 458
# ((2, 96), 14)
# 459
# ((2, 97), 16)
# 460
# ((2, 98), 23)
# 461
# ((2, 99), 13)
# 462
# ((2, 100), 14)
# 463
# ((2, 101), 15)
# 464
# ((2, 102), 8)
# 465
# ((2, 103), 7)
# 466
# ((2, 104), 17)
# 467
# ((2, 105), 15)
# 468
# ((2, 106), 17)
# 469
# ((2, 107), 36)
# 470
# ((2, 108), 8)
# 471
# ((2, 109), 13)
# 472
# ((2, 110), 12)
# 473
# ((2, 111), 16)
# 474
# ((2, 112), 9)
# 475
# ((2, 113), 11)
# 476
# ((2, 114), 21)
# 477
# ((2, 115), 15)
# 478
# ((2, 116), 13)
# 479
# ((2, 117), 9)
# 480
# ((2, 118), 15)
# 481
# ((2, 119), 13)
# 482
# ((2, 120), 19)
# 483
# ((2, 121), 11)
# 484
# ((2, 122), 17)
# 485
# ((2, 123), 16)
# 486
# ((2, 124), 9)
# 487
# ((2, 125), 10)
# 488
# ((2, 126), 6)
# 489
# ((2, 127), 21)
# 490
# ((2, 128), 20)
# 491
# ((2, 129), 16)
# 492
# ((2, 130), 12)
# 493
# ((2, 131), 17)
# 494
# ((2, 132), 14)
# 495
# ((2, 133), 7)
# 496
# ((2, 134), 16)
# 497
# ((2, 135), 11)
# 498
# ((2, 136), 7)
# 499
# ((2, 137), 12)
# 500
# ((2, 138), 8)
# 501
# ((2, 139), 7)
# 502
# ((2, 140), 10)
# 503
# ((2, 141), 9)
# 504
# ((2, 142), 10)
# 505
# ((2, 143), 18)
# 506
# ((2, 144), 16)
# 507
# ((2, 145), 12)
# 508
# ((2, 146), 13)
# 509
# ((2, 147), 7)
# 510
# ((2, 148), 9)
# 511
# ((2, 149), 13)
# 512
# ((2, 150), 7)
# 513
# ((2, 151), 14)
# 514
# ((2, 152), 7)
# 515
# ((2, 153), 11)
# 516
# ((2, 154), 17)
# 517
# ((2, 155), 14)
# 518
# ((2, 156), 12)
# 519
# ((2, 157), 7)
# 520
# ((2, 158), 14)
# 521
# ((2, 159), 19)
# 522
# ((2, 160), 18)
# 523
# ((2, 161), 14)
# 524
# ((2, 162), 10)
# 525
# ((2, 163), 18)
# 526
# ((2, 164), 12)
# 527
# ((2, 165), 17)
# 528
# ((2, 166), 11)
# 529
# ((2, 167), 14)
# 530
# ((2, 168), 13)
# 531
# ((2, 169), 11)
# 532
# ((2, 170), 7)
# 533
# ((2, 171), 16)
# 534
# ((2, 172), 8)
# 535
# ((2, 173), 16)
# 536
# ((2, 174), 18)
# 537
# ((2, 175), 11)
# 538
# ((2, 176), 20)
# 539
# ((2, 177), 13)
# 540
# ((2, 178), 19)
# 541
# ((2, 179), 15)
# 542
# ((2, 180), 13)
# 543
# ((3, 0), 14)
# 544
# ((3, 1), 7)
# 545
# ((3, 2), 9)
# 546
# ((3, 3), 15)
# 547
# ((3, 4), 8)
# 548
# ((3, 5), 16)
# 549
# ((3, 6), 13)
# 550
# ((3, 7), 11)
# 551
# ((3, 8), 17)
# 552
# ((3, 9), 13)
# 553
# ((3, 10), 18)
# 554
# ((3, 11), 13)
# 555
# ((3, 12), 15)
# 556
# ((3, 13), 15)
# 557
# ((3, 14), 19)
# 558
# ((3, 15), 17)
# 559
# ((3, 16), 16)
# 560
# ((3, 17), 13)
# 561
# ((3, 18), 13)
# 562
# ((3, 19), 10)
# 563
# ((3, 20), 9)
# 564
# ((3, 21), 13)
# 565
# ((3, 22), 15)
# 566
# ((3, 23), 12)
# 567
# ((3, 24), 10)
# 568
# ((3, 25), 12)
# 569
# ((3, 26), 11)
# 570
# ((3, 27), 17)
# 571
# ((3, 28), 16)
# 572
# ((3, 29), 11)
# 573
# ((3, 30), 19)
# 574
# ((3, 31), 17)
# 575
# ((3, 32), 6)
# 576
# ((3, 33), 7)
# 577
# ((3, 34), 12)
# 578
# ((3, 35), 20)
# 579
# ((3, 36), 13)
# 580
# ((3, 37), 8)
# 581
# ((3, 38), 7)
# 582
# ((3, 39), 11)
# 583
# ((3, 40), 8)
# 584
# ((3, 41), 17)
# 585
# ((3, 42), 18)
# 586
# ((3, 43), 14)
# 587
# ((3, 44), 16)
# 588
# ((3, 45), 14)
# 589
# ((3, 46), 40)
# 590
# ((3, 47), 14)
# 591
# ((3, 48), 17)
# 592
# ((3, 49), 6)
# 593
# ((3, 50), 13)
# 594
# ((3, 51), 19)
# 595
# ((3, 52), 18)
# 596
# ((3, 53), 9)
# 597
# ((3, 54), 16)
# 598
# ((3, 55), 7)
# 599
# ((3, 56), 19)
# 600
# ((3, 57), 9)
# 601
# ((3, 58), 12)
# 602
# ((3, 59), 13)
# 603
# ((3, 60), 7)
# 604
# ((3, 61), 15)
# 605
# ((3, 62), 15)
# 606
# ((3, 63), 15)
# 607
# ((3, 64), 16)
# 608
# ((3, 65), 11)
# 609
# ((3, 66), 11)
# 610
# ((3, 67), 18)
# 611
# ((3, 68), 28)
# 612
# ((3, 69), 19)
# 613
# ((3, 70), 17)
# 614
# ((3, 71), 10)
# 615
# ((3, 72), 10)
# 616
# ((3, 73), 17)
# 617
# ((3, 74), 17)
# 618
# ((3, 75), 11)
# 619
# ((3, 76), 47)
# 620
# ((3, 77), 8)
# 621
# ((3, 78), 10)
# 622
# ((3, 79), 17)
# 623
# ((3, 80), 16)
# 624
# ((3, 81), 9)
# 625
# ((3, 82), 9)
# 626
# ((3, 83), 12)
# 627
# ((3, 84), 21)
# 628
# ((3, 85), 10)
# 629
# ((3, 86), 13)
# 630
# ((3, 87), 13)
# 631
# ((3, 88), 12)
# 632
# ((3, 89), 12)
# 633
# ((3, 90), 8)
# 634
# ((3, 91), 21)
# 635
# ((3, 92), 11)
# 636
# ((3, 93), 9)
# 637
# ((3, 94), 19)
# 638
# ((3, 95), 9)
# 639
# ((3, 96), 18)
# 640
# ((3, 97), 18)
# 641
# ((3, 98), 14)
# 642
# ((3, 99), 12)
# 643
# ((3, 100), 10)
# 644
# ((3, 101), 16)
# 645
# ((3, 102), 14)
# 646
# ((3, 103), 13)
# 647
# ((3, 104), 15)
# 648
# ((3, 105), 15)
# 649
# ((3, 106), 12)
# 650
# ((3, 107), 24)
# 651
# ((3, 108), 11)
# 652
# ((3, 109), 10)
# 653
# ((3, 110), 14)
# 654
# ((3, 111), 15)
# 655
# ((3, 112), 12)
# 656
# ((3, 113), 15)
# 657
# ((3, 114), 8)
# 658
# ((3, 115), 14)
# 659
# ((3, 116), 14)
# 660
# ((3, 117), 9)
# 661
# ((3, 118), 12)
# 662
# ((3, 119), 7)
# 663
# ((3, 120), 16)
# 664
# ((3, 121), 8)
# 665
# ((3, 122), 19)
# 666
# ((3, 123), 10)
# 667
# ((3, 124), 25)
# 668
# ((3, 125), 13)
# 669
# ((3, 126), 7)
# 670
# ((3, 127), 6)
# 671
# ((3, 128), 7)
# 672
# ((3, 129), 13)
# 673
# ((3, 130), 12)
# 674
# ((3, 131), 9)
# 675
# ((3, 132), 14)
# 676
# ((3, 133), 11)
# 677
# ((3, 134), 14)
# 678
# ((3, 135), 12)
# 679
# ((3, 136), 17)
# 680
# ((3, 137), 8)
# 681
# ((3, 138), 11)
# 682
# ((3, 139), 12)
# 683
# ((3, 140), 18)
# 684
# ((3, 141), 14)
# 685
# ((3, 142), 11)
# 686
# ((3, 143), 10)
# 687
# ((3, 144), 10)
# 688
# ((3, 145), 13)
# 689
# ((3, 146), 16)
# 690
# ((3, 147), 13)
# 691
# ((3, 148), 6)
# 692
# ((3, 149), 6)
# 693
# ((3, 150), 10)
# 694
# ((3, 151), 14)
# 695
# ((3, 152), 16)
# 696
# ((3, 153), 10)
# 697
# ((3, 154), 12)
# 698
# ((3, 155), 15)
# 699
# ((3, 156), 6)
# 700
# ((3, 157), 10)
# 701
# ((3, 158), 12)
# 702
# ((3, 159), 13)
# 703
# ((3, 160), 10)
# 704
# ((3, 161), 10)
# 705
# ((3, 162), 10)
# 706
# ((3, 163), 13)
# 707
# ((3, 164), 11)
# 708
# ((3, 165), 13)
# 709
# ((3, 166), 8)
# 710
# ((3, 167), 19)
# 711
# ((3, 168), 15)
# 712
# ((3, 169), 14)
# 713
# ((3, 170), 21)
# 714
# ((3, 171), 7)
# 715
# ((3, 172), 10)
# 716
# ((3, 173), 17)
# 717
# ((3, 174), 16)
# 718
# ((3, 175), 14)
# 719
# ((3, 176), 13)
# 720
# ((3, 177), 16)
# 721
# ((3, 178), 17)
# 722
# ((3, 179), 20)
# 723
# ((3, 180), 13)
# 724
# ((4, 0), 14)
# 725
# ((4, 1), 6)
# 726
# ((4, 2), 17)
# 727
# ((4, 3), 11)
# 728
# ((4, 4), 12)
# 729
# ((4, 5), 10)
# 730
# ((4, 6), 6)
# 731
# ((4, 7), 11)
# 732
# ((4, 8), 14)
# 733
# ((4, 9), 23)
# 734
# ((4, 10), 11)
# 735
# ((4, 11), 13)
# 736
# ((4, 12), 9)
# 737
# ((4, 13), 13)
# 738
# ((4, 14), 12)
# 739
# ((4, 15), 13)
# 740
# ((4, 16), 8)
# 741
# ((4, 17), 15)
# 742
# ((4, 18), 11)
# 743
# ((4, 19), 17)
# 744
# ((4, 20), 17)
# 745
# ((4, 21), 15)
# 746
# ((4, 22), 17)
# 747
# ((4, 23), 10)
# 748
# ((4, 24), 16)
# 749
# ((4, 25), 13)
# 750
# ((4, 26), 12)
# 751
# ((4, 27), 22)
# 752
# ((4, 28), 9)
# 753
# ((4, 29), 7)
# 754
# ((4, 30), 9)
# 755
# ((4, 31), 10)
# 756
# ((4, 32), 17)
# 757
# ((4, 33), 17)
# 758
# ((4, 34), 10)
# 759
# ((4, 35), 9)
# 760
# ((4, 36), 12)
# 761
# ((4, 37), 10)
# 762
# ((4, 38), 8)
# 763
# ((4, 39), 14)
# 764
# ((4, 40), 16)
# 765
# ((4, 41), 18)
# 766
# ((4, 42), 76)
# 767
# ((4, 43), 25)
# 768
# ((4, 44), 11)
# 769
# ((4, 45), 15)
# 770
# ((4, 46), 13)
# 771
# ((4, 47), 17)
# 772
# ((4, 48), 10)
# 773
# ((4, 49), 4)
# 774
# ((4, 50), 9)
# 775
# ((4, 51), 8)
# 776
# ((4, 52), 13)
# 777
# ((4, 53), 6)
# 778
# ((4, 54), 7)
# 779
# ((4, 55), 15)
# 780
# ((4, 56), 10)
# 781
# ((4, 57), 10)
# 782
# ((4, 58), 16)
# 783
# ((4, 59), 13)
# 784
# ((4, 60), 10)
# 785
# ((4, 61), 16)
# 786
# ((4, 62), 10)
# 787
# ((4, 63), 13)
# 788
# ((4, 64), 8)
# 789
# ((4, 65), 22)
# 790
# ((4, 66), 13)
# 791
# ((4, 67), 13)
# 792
# ((4, 68), 14)
# 793
# ((4, 69), 7)
# 794
# ((4, 70), 9)
# 795
# ((4, 71), 14)
# 796
# ((4, 72), 7)
# 797
# ((4, 73), 8)
# 798
# ((4, 74), 17)
# 799
# ((4, 75), 20)
# 800
# ((4, 76), 10)
# 801
# ((4, 77), 17)
# 802
# ((4, 78), 10)
# 803
# ((4, 79), 18)
# 804
# ((4, 80), 16)
# 805
# ((4, 81), 9)
# 806
# ((4, 82), 8)
# 807
# ((4, 83), 17)
# 808
# ((4, 84), 21)
# 809
# ((4, 85), 10)
# 810
# ((4, 86), 17)
# 811
# ((4, 87), 10)
# 812
# ((4, 88), 11)
# 813
# ((4, 89), 12)
# 814
# ((4, 90), 20)
# 815
# ((4, 91), 11)
# 816
# ((4, 92), 13)
# 817
# ((4, 93), 14)
# 818
# ((4, 94), 14)
# 819
# 916
# ((5, 11), 7)
# 917
# ((5, 12), 10)
# 918
# ((5, 13), 15)
# 919
# ((5, 14), 16)
# 920
# ((5, 15), 13)
# 921
# ((5, 16), 4)
# 922
# ((5, 17), 10)
# 923
# ((5, 18), 17)
# 924
# ((5, 19), 4)
# 925
# ((5, 20), 17)
# 926
# ((5, 21), 13)
# 927
# ((5, 22), 13)
# 928
# ((5, 23), 16)
# 929
# ((5, 24), 9)
# 930
# ((5, 25), 14)
# 931
# ((5, 26), 12)
# 932
# ((5, 27), 16)
# 933
# ((5, 28), 14)
# 934
# ((5, 29), 9)
# 935
# ((5, 30), 13)
# 936
# ((5, 31), 14)
# 937
# ((5, 32), 11)
# 938
# ((5, 33), 13)
# 939
# ((5, 34), 16)
# 940
# ((5, 35), 9)
# 941
# ((5, 36), 16)
# 942
# ((5, 37), 10)
# 943
# ((5, 38), 9)
# 944
# ((5, 39), 7)
# 945
# ((5, 40), 10)
# 946
# ((5, 41), 11)
# 947
# ((5, 42), 9)
# 948
# ((5, 43), 6)
# 949
# ((5, 44), 9)
# 950
# ((5, 45), 3)
# 951
# ((5, 46), 15)
# 952
# ((5, 47), 10)
# 953
# ((5, 48), 13)
# 954
# ((5, 49), 7)
# 955
# ((5, 50), 16)
# 956
# ((5, 51), 14)
# 957
# ((5, 52), 9)
# 958
# ((5, 53), 16)
# 959
# ((5, 54), 15)
# 960
# ((5, 55), 12)
# 961
# ((5, 56), 6)
# 962
# ((5, 57), 9)
# 963
# ((5, 58), 10)
# 964
# ((5, 59), 13)
# 965
# ((5, 60), 10)
# 966
# ((5, 61), 11)
# 967
# ((5, 62), 12)
# 968
# ((5, 63), 10)
# 969
# ((5, 64), 5)
# 970
# ((5, 65), 17)
# 971
# ((5, 66), 6)
# 972
# ((5, 67), 8)
# 973
# ((5, 68), 13)
# 974
# ((5, 69), 10)
# 975
# ((5, 70), 9)
# 976
# ((5, 71), 12)
# 977
# ((5, 72), 9)
# 978
# ((5, 73), 13)
# 979
# ((5, 74), 15)
# 980
# ((5, 75), 13)
# 981
# ((5, 76), 13)
# 982
# ((5, 77), 9)
# 983
# ((5, 78), 9)
# 984
# ((5, 79), 7)
# 985
# ((5, 80), 14)
# 986
# ((5, 81), 8)
# 987
# ((5, 82), 12)
# 988
# ((5, 83), 13)
# 989
# ((5, 84), 9)
# 990
# ((5, 85), 22)
# 991
# ((5, 86), 17)
# 992
# ((5, 87), 17)
# 993
# ((5, 88), 5)
# 994
# ((5, 89), 12)
# 995
# ((5, 90), 11)
# 996
# ((5, 91), 12)
# 997
# ((5, 92), 11)
# 998
# ((5, 93), 13)
# 999
# ((5, 94), 14)
# 1000
# ((5, 95), 15)
# 1001
# ((5, 96), 6)
# 1002
# ((5, 97), 6)
# 1003
# ((5, 98), 8)
# 1004
# ((5, 99), 9)
# 1005
# ((5, 100), 17)
# 1006
# ((5, 101), 17)
# 1007
# ((5, 102), 14)
# 1008
# ((5, 103), 7)
# 1009
# ((5, 104), 10)
# 1010
# ((5, 105), 22)
# 1011
# ((5, 106), 20)
# 1012
# ((5, 107), 13)
# 1013
# ((5, 108), 9)
# 1014
# ((5, 109), 6)
# 1015
# ((5, 110), 8)
# 1016
# ((5, 111), 19)
# 1017
# ((5, 112), 14)
# 1018
# ((5, 113), 4)
# 1019
# ((5, 114), 11)
# 1020
# ((5, 115), 12)
# 1021
# ((5, 116), 7)
# 1022
# ((5, 117), 16)
# 1023
# ((5, 118), 11)
# 1024
# ((5, 119), 11)
# 1025
# ((5, 120), 10)
# 1026
# ((5, 121), 13)
# 1027
# ((5, 122), 15)
# 1028
# ((5, 123), 17)
# 1029
# ((5, 124), 17)
# 1030
# ((5, 125), 10)
# 1031
# ((5, 126), 10)
# 1032
# ((5, 127), 8)
# 1033
# ((5, 128), 23)
# 1034
# ((5, 129), 9)
# 1035
# ((5, 130), 9)
# 1036
# ((5, 131), 10)
# 1037
# ((5, 132), 12)
# 1038
# ((5, 133), 16)
# 1039
# ((5, 134), 19)
# 1040
# ((5, 135), 24)
# 1041
# ((5, 136), 22)
# 1042
# ((5, 137), 10)
# 1043
# ((5, 138), 15)
# 1044
# ((5, 139), 10)
# 1045
# ((5, 140), 11)
# 1046
# ((5, 141), 15)
# 1047
# ((5, 142), 11)
# 1048
# ((5, 143), 9)
# 1049
# ((5, 144), 16)
# 1050
# ((5, 145), 20)
# 1051
# ((5, 146), 14)
# 1052
# ((5, 147), 9)
# 1053
# ((5, 148), 7)
# 1054
# ((5, 149), 11)
# 1055
# ((5, 150), 20)
# 1056
# ((5, 151), 10)
# 1057
# ((5, 152), 9)
# 1058
# ((5, 153), 19)
# 1059
# ((5, 154), 11)
# 1060
# ((5, 155), 9)
# 1061
# ((5, 156), 6)
# 1062
# ((5, 157), 10)
# 1063
# ((5, 158), 9)
# 1064
# ((5, 159), 9)
# 1065
# ((5, 160), 5)
# 1066
# ((5, 161), 11)
# 1067
# ((5, 162), 13)
# 1068
# ((5, 163), 20)
# 1069
# ((5, 164), 14)
# 1070
# ((5, 165), 13)
# 1071
# ((5, 166), 18)
# 1072
# ((5, 167), 10)
# 1073
# ((5, 168), 15)
# 1074
# ((5, 169), 20)
# 1075
# ((5, 170), 17)
# 1076
# ((5, 171), 16)
# 1077
# ((5, 172), 16)
# 1078
# ((5, 173), 17)
# 1079
# ((5, 174), 8)
# 1080
# ((5, 175), 17)
# 1081
# ((5, 176), 18)
# 1082
# ((5, 177), 11)
# 1083
# ((5, 178), 9)
# 1084
# ((5, 179), 15)
# 1085
# ((5, 180), 22)
# 1086
# ((6, 0), 13)
# 1087
# ((6, 1), 8)
# 1088
# ((6, 2), 13)
# 1089
# ((6, 3), 8)
# 1090
# ((6, 4), 10)
# 1091
# ((6, 5), 7)
# 1092
# ((6, 6), 22)
# 1093
# ((6, 7), 9)
# 1094
# ((6, 8), 17)
# 1095
# ((6, 9), 18)
# 1096
# ((6, 10), 14)
# 1097
# ((6, 11), 14)
# 1098
# ((6, 12), 13)
# 1099
# ((6, 13), 14)
# 1100
# ((6, 14), 14)
# 1101
# ((6, 15), 10)
# ((7, 16), 11)
# 1284
# ((7, 17), 11)
# 1285
# ((7, 18), 10)
# 1286
# ((7, 19), 19)
# 1287
# ((7, 20), 11)
# 1288
# ((7, 21), 14)
# 1289
# ((7, 22), 10)
# 1290
# ((7, 23), 20)
# 1291
# ((7, 24), 11)
# 1292
# ((7, 25), 20)
# 1293
# ((7, 26), 14)
# 1294
# ((7, 27), 15)
# 1295
# ((7, 28), 17)
# 1296
# ((7, 29), 7)
# 1297
# ((7, 30), 7)
# 1298
# ((7, 31), 5)
# 1299
# ((7, 32), 9)
# 1300
# ((7, 33), 19)
# 1301
# ((7, 34), 15)
# 1302
# ((7, 35), 13)
# 1303
# ((7, 36), 16)
# 1304
# ((7, 37), 15)
# 1305
# ((7, 38), 19)
# 1306
# ((7, 39), 14)
# 1307
# ((7, 40), 11)
# 1308
# ((7, 41), 10)
# 1309
# ((7, 42), 10)
# 1310
# ((7, 43), 7)
# 1311
# ((7, 44), 17)
# 1312
# ((7, 45), 18)
# 1313
# ((7, 46), 13)
# 1314
# ((7, 47), 9)
# 1315
# ((7, 48), 13)
# 1316
# ((7, 49), 16)
# 1317
# ((7, 50), 12)
# 1318
# ((7, 51), 25)
# 1319
# ((7, 52), 18)
# 1320
# ((7, 53), 15)
# 1321
# ((7, 54), 9)
# 1322
# ((7, 55), 16)
# 1323
# ((7, 56), 7)
# 1324
# ((7, 57), 14)
# 1325
# ((7, 58), 21)
# 1326
# ((7, 59), 22)
# 1327
# ((7, 60), 19)
# 1328
# ((7, 61), 17)
# 1329
# ((7, 62), 17)
# 1330
# ((7, 63), 15)
# 1331
# ((7, 64), 11)
# 1332
# ((7, 65), 7)
# 1333
# ((7, 66), 10)
# 1334
# ((7, 67), 18)
# 1335
# ((7, 68), 16)
# 1336
# ((7, 69), 10)
# 1337
# ((7, 70), 11)
# 1338
# ((7, 71), 14)
# 1339
# ((7, 72), 17)
# 1340
# ((7, 73), 14)
# 1341
# ((7, 74), 9)
# 1342
# ((7, 75), 17)
# 1343
# ((7, 76), 10)
# 1344
# ((7, 77), 5)
# 1345
# ((7, 78), 14)
# 1346
# ((7, 79), 12)
# 1347
# ((7, 80), 13)
# 1348
# ((7, 81), 9)
# 1349
# ((7, 82), 10)
# 1350
# ((7, 83), 12)
# 1351
# ((7, 84), 12)
# 1352
# ((7, 85), 11)
# 1353
# ((7, 86), 15)
# 1354
# ((7, 87), 16)
# 1355
# ((7, 88), 4)
# 1356
# ((7, 89), 13)
# 1357
# ((7, 90), 11)
# 1358
# ((7, 91), 13)
# 1359
# ((7, 92), 13)
# 1360
# ((7, 93), 12)
# 1361
# ((7, 94), 19)
# 1362
# ((7, 95), 18)
# 1363
# ((7, 96), 13)
# 1364
# ((7, 97), 12)
# 1365
# ((7, 98), 21)
# 1366
# ((7, 99), 16)
# 1367
# ((7, 100), 6)
# 1368
# ((7, 101), 7)
# 1369
# ((7, 102), 19)
# 1370
# ((7, 103), 16)
# 1371
# ((7, 104), 18)
# 1372
# ((7, 105), 7)
# 1373
# ((7, 106), 17)
# 1374
# ((7, 107), 9)
# 1375
# ((7, 108), 10)
# 1376
# ((7, 109), 8)
# 1377
# ((7, 110), 15)
# 1378
# ((7, 111), 16)
# 1379
# ((7, 112), 14)
# 1380
# ((7, 113), 16)
# 1381
# ((7, 114), 16)
# 1382
# ((7, 115), 12)
# 1383
# ((7, 116), 10)
# 1384
# ((7, 117), 15)
# 1385
# ((7, 118), 15)
# 1386
# ((7, 119), 13)
# 1387
# ((7, 120), 23)
# 1388
# ((7, 121), 22)
# 1389
# ((7, 122), 18)
# 1390
# ((7, 123), 16)
# 1391
# ((7, 124), 10)
# 1392
# ((7, 125), 5)
# 1393
# ((7, 126), 19)
# 1394
# ((7, 127), 16)
# 1395
# ((7, 128), 13)
# 1396
# ((7, 129), 11)
# 1397
# ((7, 130), 13)
# 1398
# ((7, 131), 18)
# 1399
# ((7, 132), 12)
# 1400
# ((7, 133), 16)
# 1401
# ((7, 134), 7)
# 1402
# ((7, 135), 6)
# 1403
# ((7, 136), 13)
# 1404
# ((7, 137), 22)
# 1405
# ((7, 138), 15)
# 1406
# ((7, 139), 12)
# 1407
# ((7, 140), 10)
# 1408
# ((7, 141), 6)
# 1409
# ((7, 142), 16)
# 1410
# ((7, 143), 10)
# 1411
# ((7, 144), 21)
# 1412
# ((7, 145), 15)
# 1413
# ((7, 146), 13)
# 1414
# ((7, 147), 21)
# 1415
# ((7, 148), 14)
# 1416
# ((7, 149), 14)
# 1417
# ((7, 150), 7)
# 1418
# ((7, 151), 9)
# 1419
# ((7, 152), 6)
# 1420
# ((7, 153), 12)
# 1421
# ((7, 154), 15)
# 1422
# ((7, 155), 20)
# 1423
# ((7, 156), 12)
# 1424
# ((7, 157), 24)
# 1425
# ((7, 158), 16)
# 1426
# ((7, 159), 13)
# 1427
# ((7, 160), 21)
# 1428
# ((7, 161), 12)
# 1429
# ((7, 162), 20)
# 1430
# ((7, 163), 15)
# 1431
# ((7, 164), 9)
# 1432
# ((7, 165), 16)
# 1433
# ((7, 166), 10)
# 1434
# ((7, 167), 12)
# 1435
# ((7, 168), 22)
# 1436
# ((7, 169), 19)
# 1437
# ((7, 170), 15)
# 1438
# ((7, 171), 12)
# 1439
# ((7, 172), 19)
# 1440
# ((7, 173), 12)
# 1441
# ((7, 174), 20)
# 1442
# ((7, 175), 18)
# 1443
# ((7, 176), 15)
# 1444
# ((7, 177), 15)
# 1445
# ((7, 178), 6)
# 1446
# ((7, 179), 21)
# 1447
# ((7, 180), 25)
# 1448
# ((8, 0), 12)
# 1449
# ((8, 1), 13)
# 1450
# ((8, 2), 15)
# 1451
# ((8, 3), 22)
# 1452
# ((8, 4), 8)
# 1453
# ((8, 5), 10)
# 1454
# ((8, 6), 13)
# 1455
# ((8, 7), 20)
# 1456
# ((8, 8), 21)
# 1457
# ((8, 9), 22)
# 1458
# ((8, 10), 10)
# 1459
# ((8, 11), 13)
# 1460
# ((8, 12), 20)
# 1461
# ((8, 13), 10)
# 1462
# ((8, 14), 12)
# 1463
# ((8, 15), 9)
# 1464
# ((8, 16), 17)
# ((9, 17), 10)
# 1647
# ((9, 18), 4)
# 1648
# ((9, 19), 16)
# 1649
# ((9, 20), 12)
# 1650
# ((9, 21), 11)
# 1651
# ((9, 22), 9)
# 1652
# ((9, 23), 13)
# 1653
# ((9, 24), 16)
# 1654
# ((9, 25), 12)
# 1655
# ((9, 26), 10)
# 1656
# ((9, 27), 15)
# 1657
# ((9, 28), 13)
# 1658
# ((9, 29), 15)
# 1659
# ((9, 30), 10)
# 1660
# ((9, 31), 8)
# 1661
# ((9, 32), 7)
# 1662
# ((9, 33), 10)
# 1663
# ((9, 34), 11)
# 1664
# ((9, 35), 10)
# 1665
# ((9, 36), 10)
# 1666
# ((9, 37), 10)
# 1667
# ((9, 38), 16)
# 1668
# ((9, 39), 16)
# 1669
# ((9, 40), 11)
# 1670
# ((9, 41), 12)
# 1671
# ((9, 42), 11)
# 1672
# ((9, 43), 18)
# 1673
# ((9, 44), 10)
# 1674
# ((9, 45), 5)
# 1675
# ((9, 46), 12)
# 1676
# ((9, 47), 12)
# 1677
# ((9, 48), 9)
# 1678
# ((9, 49), 14)
# 1679
# ((9, 50), 5)
# 1680
# ((9, 51), 13)
# 1681
# ((9, 52), 20)
# 1682
# ((9, 53), 5)
# 1683
# ((9, 54), 16)
# 1684
# ((9, 55), 18)
# 1685
# ((9, 56), 16)
# 1686
# ((9, 57), 11)
# 1687
# ((9, 58), 8)
# 1688
# ((9, 59), 16)
# 1689
# ((9, 60), 11)
# 1690
# ((9, 61), 8)
# 1691
# ((9, 62), 10)
# 1692
# ((9, 63), 8)
# 1693
# ((9, 64), 12)
# 1694
# ((9, 65), 13)
# 1695
# ((9, 66), 19)
# 1696
# ((9, 67), 10)
# 1697
# ((9, 68), 13)
# 1698
# ((9, 69), 19)
# 1699
# ((9, 70), 20)
# 1700
# ((9, 71), 19)
# 1701
# ((9, 72), 10)
# 1702
# ((9, 73), 22)
# 1703
# ((9, 74), 17)
# 1704
# ((9, 75), 14)
# 1705
# ((9, 76), 10)
# 1706
# ((9, 77), 10)
# 1707
# ((9, 78), 13)
# 1708
# ((9, 79), 20)
# 1709
# ((9, 80), 13)
# 1710
# ((9, 81), 11)
# 1711
# ((9, 82), 23)
# 1712
# ((9, 83), 32)
# 1713
# ((9, 84), 9)
# 1714
# ((9, 85), 18)
# 1715
# ((9, 86), 10)
# 1716
# ((9, 87), 18)
# 1717
# ((9, 88), 10)
# 1718
# ((9, 89), 9)
# 1719
# ((9, 90), 8)
# 1720
# ((9, 91), 7)
# 1721
# ((9, 92), 18)
# 1722
# ((9, 93), 5)
# 1723
# ((9, 94), 12)
# 1724
# ((9, 95), 8)
# 1725
# ((9, 96), 13)
# 1726
# ((9, 97), 13)
# 1727
# ((9, 98), 14)
# 1728
# ((9, 99), 11)
# 1729
# ((9, 100), 5)
# 1730
# ((9, 101), 13)
# 1731
# ((9, 102), 13)
# 1732
# ((9, 103), 22)
# 1733
# ((9, 104), 13)
# 1734
# ((9, 105), 12)
# 1735
# ((9, 106), 6)
# 1736
# ((9, 107), 11)
# 1737
# 2191
# ((12, 19), 8)
# 2192
# ((12, 20), 10)
# 2193
# ((12, 21), 12)
# 2194
# ((12, 22), 18)
# 2195
# ((12, 23), 18)
# 2196
# ((12, 24), 6)
# 2197
# ((12, 25), 10)
# 2198
# ((12, 26), 17)
# 2199
# ((12, 27), 9)
# 2200
# ((12, 28), 15)
# 2201
# ((12, 29), 8)
# 2202
# ((12, 30), 10)
# 2203
# ((12, 31), 12)
# 2204
# ((12, 32), 18)
# 2205
# ((12, 33), 17)
# 2206
# ((12, 34), 13)
# 2207
# ((12, 35), 17)
# 2208
# ((12, 36), 13)
# 2209
# ((12, 37), 12)
# 2210
# ((12, 38), 9)
# 2211
# ((12, 39), 18)
# 2212
# ((12, 40), 13)
# 2213
# ((12, 41), 9)
# 2214
# ((12, 42), 17)
# 2215
# ((12, 43), 8)
# 2216
# ((12, 44), 11)
# 2217
# ((12, 45), 7)
# 2218
# ((12, 46), 15)
# 2219
# ((12, 47), 9)
# 2220
# ((12, 48), 11)
# 2221
# ((12, 49), 12)
# 2222
# ((12, 50), 12)
# 2223
# ((12, 51), 13)
# 2224
# ((12, 52), 16)
# 2225
# ((12, 53), 5)
# 2226
# ((12, 54), 7)
# 2227
# ((12, 55), 17)
# 2228
# ((12, 56), 12)
# 2229
# ((12, 57), 13)
# 2230
# ((12, 58), 16)
# 2231
# ((12, 59), 10)
# 2232
# ((12, 60), 16)
# 2233
# ((12, 61), 19)
# 2234
# ((12, 62), 13)
# 2235
# ((12, 63), 18)
# 2236
# ((12, 64), 13)
# 2237
# ((12, 65), 16)
# 2238
# ((12, 66), 10)
# 2239
# ((12, 67), 16)
# 2240
# ((12, 68), 14)
# 2241
# ((12, 69), 8)
# 2242
# ((12, 70), 13)
# 2243
# ((12, 71), 11)
# 2244
# ((12, 72), 12)
# 2245
# ((12, 73), 21)
# 2246
# ((12, 74), 18)
# 2247
# ((12, 75), 7)
# 2248
# ((12, 76), 13)
# 2249
# ((12, 77), 6)
# 2250
# ((12, 78), 16)
# 2251
# ((12, 79), 5)
# 2252
# ((12, 80), 11)
# 2253
# ((12, 81), 7)
# 2254
# ((12, 82), 11)
# 2255
# ((12, 83), 9)
# 2256
# ((12, 84), 24)
# 2257
# ((12, 85), 10)
# 2258
# ((12, 86), 17)
# 2259
# ((12, 87), 14)
# 2260
# ((12, 88), 16)
# 2261
# ((12, 89), 8)
# 2262
# ((12, 90), 10)
# 2263
# ((12, 91), 10)
# 2264
# ((12, 92), 14)
# 2265
# ((12, 93), 10)
# 2266
# ((12, 94), 15)
# 2267
# ((12, 95), 20)
# 2268
# ((12, 96), 11)
# 2269
# ((12, 97), 20)
# 2270
# ((12, 98), 10)
# 2271
# ((12, 99), 16)
# 2272
# ((12, 100), 19)
# 2273
# ((12, 101), 12)
# 2274
# ((12, 102), 10)
# 2275
# ((12, 103), 10)
# 2276
# ((12, 104), 9)
# 2277
# ((12, 105), 13)
# 2278
# ((12, 106), 12)
# 2279
# ((12, 107), 9)
# 2280
# ((12, 108), 6)
# 2281
# ((12, 109), 15)
# 2282
# ((12, 110), 11)
# 2283
# ((12, 111), 13)
# 2284
# ((12, 112), 10)
# 2285
# ((12, 113), 14)
# 2286
# ((12, 114), 24)
# 2287
# ((12, 115), 9)
# 2288
# ((12, 116), 8)
# 2289
# ((12, 117), 14)
# 2290
# ((12, 118), 10)
# 2291
# ((12, 119), 11)
# 2292
# ((12, 120), 11)
# 2293
# ((12, 121), 8)
# 2294
# ((12, 122), 10)
# 2295
# ((12, 123), 12)
# 2296
# ((12, 124), 11)
# 2297
# ((12, 125), 8)
# 2298
# ((12, 126), 18)
# 2299
# ((12, 127), 11)
# 2300
# ((12, 128), 19)
# 2301
# ((12, 129), 15)
# 2302
# ((12, 130), 14)
# 2303
# ((12, 131), 16)
# 2304
# ((12, 132), 13)
# 2305
# ((12, 133), 22)
# 2306
# ((12, 134), 9)
# 2307
# ((12, 135), 9)
# 2308
# ((12, 136), 23)
# 2309
# ((12, 137), 12)
# 2310
# ((12, 138), 19)
# 2311
# ((12, 139), 16)
# 2312
# ((12, 140), 19)
# 2313
# ((12, 141), 14)
# 2314
# ((12, 142), 9)
# 2315
# ((12, 143), 14)
# 2316
# ((12, 144), 22)
# 2317
# ((12, 145), 11)
# 2318
# ((12, 146), 13)
# 2319
# ((12, 147), 12)
# 2320
# ((12, 148), 23)
# 2321
# ((12, 149), 7)
# 2322
# ((12, 150), 7)
# 2323
# ((12, 151), 16)
# 2324
# ((12, 152), 9)
# 2325
# ((12, 153), 19)
# 2326
# ((12, 154), 10)
# 2327
# ((12, 155), 15)
# 2328
# ((12, 156), 14)
# 2329
# ((12, 157), 28)
# 2330
# ((12, 158), 7)
# 2331
# ((12, 159), 11)
# 2332
# ((12, 160), 15)
# 2333
# ((12, 161), 16)
# 2334
# ((12, 162), 10)
# 2335
# ((12, 163), 18)
# 2336
# ((12, 164), 23)
# 2337
# ((12, 165), 14)
# 2338
# ((12, 166), 6)
# 2339
# ((12, 167), 17)
# 2340
# ((12, 168), 9)
# 2341
# ((12, 169), 12)
# 2342
# ((12, 170), 10)
# 2343
# ((12, 171), 10)
# 2344
# ((12, 172), 16)
# 2345
# ((12, 173), 17)
# 2346
# ((12, 174), 15)
# 2347
# ((12, 175), 19)
# 2348
# ((12, 176), 11)
# 2349
# ((12, 177), 19)
# 2350
# ((12, 178), 16)
# 2351
# ((12, 179), 14)
# 2352
# ((12, 180), 15)
# 2353
# ((13, 0), 19)
# 2354
# ((13, 1), 17)
# 2355
# ((13, 2), 9)
# 2356
# ((13, 3), 12)
# 2357
# ((13, 4), 19)
# 2358
# ((13, 5), 9)
# 2359
# ((13, 6), 12)
# 2360
# ((13, 7), 11)
# 2361
# ((13, 8), 12)
# 2362
# ((13, 9), 19)
# 2363
# ((13, 10), 11)
# 2364
# ((13, 11), 16)
# 2365
# ((13, 12), 21)
# 2366
# ((13, 13), 46)
# 2367
# ((13, 14), 10)
# 2368
# ((13, 15), 10)
# 2369
# ((13, 16), 5)
# 2370
# ((13, 17), 20)
# 2371
# ((13, 18), 15)
# 2372
# 2463
# ((13, 110), 13)
# 2464
# ((13, 111), 8)
# 2465
# ((13, 112), 12)
# 2466
# ((13, 113), 10)
# 2467
# ((13, 114), 20)
# 2468
# ((13, 115), 39)
# 2469
# ((13, 116), 13)
# 2470
# ((13, 117), 11)
# 2471
# ((13, 118), 15)
# 2472
# ((13, 119), 16)
# 2473
# ((13, 120), 10)
# 2474
# ((13, 121), 11)
# 2475
# ((13, 122), 15)
# 2476
# ((13, 123), 14)
# 2477
# ((13, 124), 9)
# 2478
# ((13, 125), 15)
# 2479
# ((13, 126), 16)
# 2480
# ((13, 127), 13)
# 2481
# ((13, 128), 15)
# 2482
# ((13, 129), 13)
# 2483
# ((13, 130), 8)
# 2484
# ((13, 131), 16)
# 2485
# ((13, 132), 15)
# 2486
# ((13, 133), 13)
# 2487
# ((13, 134), 9)
# 2488
# ((13, 135), 9)
# 2489
# ((13, 136), 12)
# 2490
# ((13, 137), 20)
# 2491
# ((13, 138), 19)
# 2492
# ((13, 139), 12)
# 2493
# ((13, 140), 14)
# 2494
# ((13, 141), 7)
# 2495
# ((13, 142), 6)
# 2496
# ((13, 143), 12)
# 2497
# ((13, 144), 17)
# 2498
# ((13, 145), 10)
# 2499
# ((13, 146), 4)
# 2500
# ((13, 147), 18)
# 2501
# ((13, 148), 14)
# 2502
# ((13, 149), 17)
# 2503
# ((13, 150), 11)
# 2504
# ((13, 151), 18)
# 2505
# ((13, 152), 13)
# 2506
# ((13, 153), 10)
# 2507
# ((13, 154), 5)
# 2508
# ((13, 155), 13)
# 2509
# ((13, 156), 15)
# 2510
# ((13, 157), 24)
# 2511
# ((13, 158), 10)
# 2512
# ((13, 159), 9)
# 2513
# ((13, 160), 12)
# 2514
# ((13, 161), 17)
# 2515
# ((13, 162), 17)
# 2516
# ((13, 163), 24)
# 2517
# ((13, 164), 15)
# 2518
# ((13, 165), 8)
# 2519
# ((13, 166), 13)
# 2520
# ((13, 167), 19)
# 2521
# ((13, 168), 23)
# 2522
# ((13, 169), 15)
# 2523
# ...
# ((176, 175), 13)
# 32032
# ((176, 176), 13)
# 32033
# ((176, 177), 33)
# 32034
# ((176, 178), 11)
# 32035
# ((176, 179), 4)
# 32036
# ((176, 180), 7)
# 32037
# ((177, 0), 8)
# 32038
# ((177, 1), 8)
# 32039
# ((177, 2), 8)
# 32040
# ((177, 3), 10)
# 32041
# ((177, 4), 3)
# 32042
# ((177, 5), 7)
# 32043
# ((177, 6), 7)
# 32044
# ((177, 7), 6)
# 32045
# ((177, 8), 19)
# 32046
# ((177, 9), 13)
# 32047
# ((177, 10), 4)
# 32048
# ((177, 11), 12)
# 32049
# ((177, 12), 32)
# 32050
# ((177, 13), 12)
# 32051
# ((177, 14), 6)
# 32052
# ((177, 15), 12)
# 32053
# ((177, 16), 9)
# 32054
# ((177, 17), 20)
# 32055
# ((177, 18), 17)
# 32056
# ((177, 19), 2)
# 32057
# ((177, 20), 1)
# 32058
# ((177, 21), 5)
# 32059
# ((177, 22), 4)
# 32060
# ((177, 23), 13)
# 32061
# ((177, 24), 8)
# 32062
# ((177, 25), 11)
# 32063
# ((177, 26), 13)
# 32064
# ((177, 27), 19)
# 32065
# ((177, 28), 29)
# 32066
# ((177, 29), 29)
# 32067
# ((177, 30), 25)
# 32068
# ((177, 31), 12)
# 32069
# ((177, 32), 9)
# 32070
# ((177, 33), 11)
# 32071
# ((177, 34), 7)
# 32072
# ((177, 35), 20)
# 32073
# ((177, 36), 15)
# 32074
# ((177, 37), 9)
# 32075
# ((177, 38), 18)
# 32076
# ((177, 39), 6)
# 32077
# ((177, 40), 4)
# 32078
# ((177, 41), 8)
# 32079
# ((177, 42), 9)
# 32080
# ((177, 43), 10)
# 32081
# ((177, 44), 7)
# 32082
# ((177, 45), 6)
# 32083
# ((177, 46), 8)
# 32084
# ((177, 47), 7)
# 32085
# ((177, 48), 2)
# 32086
# ((177, 49), 8)
# 32087
# ((177, 50), 7)
# 32088
# ((177, 51), 9)
# 32089
# ((177, 52), 15)
# 32090
# ((177, 53), 3)
# 32091
# ((177, 54), 13)
# 32092
# ((177, 55), 7)
# 32093
# ((177, 56), 9)
# 32094
# ((177, 57), 30)
# 32095
# ((177, 58), 13)
# 32096
# ((177, 59), 6)
# 32097
# ((177, 60), 9)
# 32098
# ((177, 61), 14)
# 32099
# ((177, 62), 5)
# 32100
# ((177, 63), 8)
# 32101
# ((177, 64), 6)
# 32102
# ((177, 65), 2)
# 32103
# ((177, 66), 5)
# 32104
# ((177, 67), 8)
# 32105
# ((177, 68), 11)
# 32106
# ((177, 69), 9)
# 32107
# ((177, 70), 11)
# 32108
# ((177, 71), 9)
# 32109
# ((177, 72), 7)
# 32110
# ((177, 73), 4)
# 32111
# ((177, 74), 8)
# 32112
# ((177, 75), 8)
# 32113
# ((177, 76), 11)
# 32114
# ((177, 77), 10)
# 32115
# ((177, 78), 8)
# 32116
# ((177, 79), 12)
# 32117
# ((177, 80), 7)
# 32118
# ((177, 81), 7)
# 32119
# ((177, 82), 11)
# 32120
# ((177, 83), 23)
# 32121
# ((177, 84), 6)
# 32122
# ((177, 85), 6)
# 32123
# ((177, 86), 16)
# 32124
# ((177, 87), 6)
# 32125
# ((177, 88), 5)
# 32126
# ((177, 89), 6)
# 32127
# ((177, 90), 7)
# 32128
# ((177, 91), 21)
# 32129
# ((177, 92), 7)
# 32130
# ((177, 93), 11)
# 32131
# ((177, 94), 17)
# 32132
# ((177, 95), 10)
# 32133
# ((177, 96), 6)
# 32134
# ((177, 97), 3)
# 32135
# ((177, 98), 8)
# 32136
# ((177, 99), 29)
# 32137
# ((177, 100), 76)
# 32138
# ((177, 101), 33)
# 32139
# ((177, 102), 13)
# 32140
# ((177, 103), 12)
# 32141
# ((177, 104), 7)
# 32142
# ((177, 105), 61)
# 32143
# ((177, 106), 7)
# 32144
# ((177, 107), 15)
# 32145
# ((177, 108), 30)
# 32146
# ((177, 109), 9)
# 32147
# ((177, 110), 10)
# 32148
# ((177, 111), 14)
# 32149
# ((177, 112), 7)
# 32150
# ((177, 113), 11)
# 32151
# ((177, 114), 77)
# 32152
# ((177, 115), 42)
# 32153
# ((177, 116), 12)
# 32154
# ((177, 117), 5)
# 32155
# ((177, 118), 12)
# 32156
# ((177, 119), 4)
# 32157
# ((177, 120), 6)
# 32158
# ((177, 121), 16)
# 32159
# ((177, 122), 7)
# 32160
# ((177, 123), 15)
# 32161
# ((177, 124), 11)
# 32162
# ((177, 125), 7)
# 32163
# ((177, 126), 5)
# 32164
# ((177, 127), 3)
# 32165
# ((177, 128), 10)
# 32166
# ((177, 129), 8)
# 32167
# ((177, 130), 11)
# 32168
# ((177, 131), 8)
# 32169
# ((177, 132), 7)
# 32170
# ((177, 133), 10)
# 32171
# ((177, 134), 9)
# 32172
# ((177, 135), 21)
# 32173
# ((177, 136), 19)
# 32174
# ((177, 137), 15)
# 32175
# ((177, 138), 12)
# 32176
# ((177, 139), 13)
# 32177
# ((177, 140), 7)
# 32178
# ((177, 141), 7)
# 32179
# ((177, 142), 8)
# 32180
# ((177, 143), 7)
# 32181
# ((177, 144), 6)
# 32182
# ((177, 145), 5)
# 32183
# ((177, 146), 14)
# 32184
# ((177, 147), 8)
# 32185
# ((177, 148), 12)
# 32186
# ((177, 149), 13)
# 32187
# ((177, 150), 6)
# 32188
# ((177, 151), 7)
# 32189
# ((177, 152), 18)
# 32190
# ((177, 153), 77)
# 32191
# ((177, 154), 7)
# 32192
# ((177, 155), 13)
# 32193
# ((177, 156), 8)
# 32194
# ((177, 157), 11)
# 32195
# ((177, 158), 16)
# 32196
# ((177, 159), 33)
# 32197
# ((177, 160), 22)
# 32198
# ((177, 161), 6)
# 32199
# ((177, 162), 7)
# 32200
# ((177, 163), 11)
# 32201
# ((177, 164), 7)
# 32202
# ((177, 165), 6)
# 32203
# ((177, 166), 24)
# 32204
# ((177, 167), 76)
# 32205
# ((177, 168), 76)
# 32206
# ((177, 169), 71)
# 32207
# ((177, 170), 16)
# 32208
# ((177, 171), 76)
# 32209
# ((177, 172), 26)
# 32210
# ((177, 173), 7)
# 32211
# ((177, 174), 76)
# 32212
# ((177, 175), 17)
# 32213
# ((177, 176), 18)
# 32214
# ((177, 177), 12)
# 32215
# ((177, 178), 19)
# 32216
# ((177, 179), 9)
# 32217
# ((177, 180), 7)
# 32218
# ((178, 0), 7)
# 32219
# ((178, 1), 13)
# 32220
# ((178, 2), 8)
# 32221
# ((178, 3), 8)
# 32222
# ((178, 4), 4)
# 32223
# ((178, 5), 16)
# 32224
# ((178, 6), 6)
# 32225
# ((178, 7), 15)
# 32226
# ((178, 8), 6)
# 32227
# ((178, 9), 7)
# 32228
# ((178, 10), 11)
# 32229
# ((178, 11), 4)
# 32230
# ((178, 12), 7)
# 32231
# ((178, 13), 11)
# 32232
# ((178, 14), 9)
# 32233
# ((178, 15), 4)
# 32234
# ((178, 16), 10)
# 32235
# ((178, 17), 16)
# 32236
# ((178, 18), 4)
# 32237
# ((178, 19), 6)
# 32238
# ((178, 20), 6)
# 32239
# ((178, 21), 9)
# 32240
# ((178, 22), 8)
# 32241
# ((178, 23), 7)
# 32242
# ((178, 24), 7)
# 32243
# ((178, 25), 13)
# 32244
# ((178, 26), 9)
# 32245
# ((178, 27), 57)
# 32246
# ((178, 28), 76)
# 32247
# ((178, 29), 75)
# 32248
# ((178, 30), 77)
# 32249
# ((178, 31), 20)
# 32250
# ((178, 32), 11)
# 32251
# ((178, 33), 12)
# 32252
# ((178, 34), 10)
# 32253
# ((178, 35), 18)
# 32254
# ((178, 36), 14)
# 32255
# ((178, 37), 12)
# 32256
# ((178, 38), 8)
# 32257
# ((178, 39), 9)
# 32258
# ((178, 40), 8)
# 32259
# ((178, 41), 5)
# 32260
# ((178, 42), 6)
# 32261
# ((178, 43), 8)
# 32262
# ((178, 44), 5)
# 32263
# ((178, 45), 7)
# 32264
# ((178, 46), 8)
# 32265
# ((178, 47), 8)
# 32266
# ((178, 48), 8)
# 32267
# ((178, 49), 3)
# 32268
# ((178, 50), 9)
# 32269
# ((178, 51), 9)
# 32270
# ((178, 52), 14)
# 32271
# ((178, 53), 7)
# 32272
# ((178, 54), 7)
# 32273
# ((178, 55), 8)
# 32274
# ((178, 56), 17)
# 32275
# ((178, 57), 14)
# 32276
# ((178, 58), 8)
# 32277
# ((178, 59), 13)
# 32278
# ((178, 60), 10)
# 32279
# ((178, 61), 6)
# 32280
# ((178, 62), 8)
# 32281
# ((178, 63), 4)
# 32282
# ((178, 64), 6)
# 32283
# ((178, 65), 9)
# 32284
# ((178, 66), 13)
# 32285
# ((178, 67), 7)
# 32286
# ((178, 68), 3)
# 32287
# ((178, 69), 9)
# 32288
# ((178, 70), 10)
# 32289
# ((178, 71), 7)
# 32290
# ((178, 72), 11)
# 32291
# ((178, 73), 10)
# 32292
# ((178, 74), 9)
# 32293
# ((178, 75), 11)
# 32294
# ((178, 76), 7)
# 32295
# ((178, 77), 10)
# 32296
# ((178, 78), 11)
# 32297
# ((178, 79), 14)
# 32298
# ((178, 80), 11)
# 32299
# ((178, 81), 10)
# 32300
# ((178, 82), 7)
# 32301
# ((178, 83), 11)
# 32302
# ((178, 84), 9)
# 32303
# ((178, 85), 9)
# 32304
# ((178, 86), 10)
# 32305
# ((178, 87), 10)
# 32306
# ((178, 88), 5)
# 32307
# ((178, 89), 17)
# 32308
# ((178, 90), 10)
# 32309
# ((178, 91), 10)
# 32310
# ((178, 92), 6)
# 32311
# ((178, 93), 8)
# 32312
# ((178, 94), 19)
# 32313
# ((178, 95), 10)
# 32314
# ((178, 96), 28)
# 32315
# ((178, 97), 18)
# 32316
# ((178, 98), 10)
# 32317
# ((178, 99), 15)
# 32318
# ((178, 100), 22)
# 32319
# ((178, 101), 11)
# 32320
# ((178, 102), 7)
# 32321
# ((178, 103), 8)
# 32322
# ((178, 104), 7)
# 32323
# ((178, 105), 11)
# 32324
# ((178, 106), 10)
# 32325
# ((178, 107), 10)
# 32326
# ((178, 108), 3)
# 32327
# ((178, 109), 10)
# 32328
# ((178, 110), 16)
# 32329
# ((178, 111), 11)
# 32330
# ((178, 112), 10)
# 32331
# ((178, 113), 5)
# 32332
# ((178, 114), 6)
# 32333
# ((178, 115), 6)
# 32334
# ((178, 116), 57)
# 32335
# ((178, 117), 15)
# 32336
# ((178, 118), 6)
# 32337
# ((178, 119), 11)
# 32338
# ((178, 120), 6)
# 32339
# ((178, 121), 12)
# 32340
# ((178, 122), 8)
# 32341
# ((178, 123), 9)
# 32342
# ((178, 124), 10)
# 32343
# ((178, 125), 10)
# 32344
# ((178, 126), 8)
# 32345
# ((178, 127), 14)
# 32346
# ((178, 128), 8)
# 32347
# ((178, 129), 6)
# 32348
# ((178, 130), 6)
# 32349
# ((178, 131), 3)
# 32350
# ((178, 132), 14)
# 32351
# ((178, 133), 10)
# 32352
# ((178, 134), 12)
# 32353
# ((178, 135), 10)
# 32354
# ((178, 136), 8)
# 32355
# ((178, 137), 11)
# 32356
# ((178, 138), 15)
# 32357
# ((178, 139), 25)
# 32358
# ((178, 140), 10)
# 32359
# ((178, 141), 9)
# 32360
# ((178, 142), 13)
# 32361
# ((178, 143), 7)
# 32362
# ((178, 144), 12)
# 32363
# ((178, 145), 7)
# 32364
# ((178, 146), 7)
# 32365
# ((178, 147), 10)
# 32366
# ((178, 148), 7)
# 32367
# ((178, 149), 13)
# 32368
# ((178, 150), 12)
# 32369
# ((178, 151), 12)
# 32370
# ((178, 152), 10)
# 32371
# ((178, 153), 10)
# 32372
# ((178, 154), 19)
# 32373
# ((178, 155), 9)
# 32374
# ((178, 156), 12)
# 32375
# ((178, 157), 15)
# 32376
# ((178, 158), 12)
# 32377
# ((178, 159), 10)
# 32378
# ((178, 160), 15)
# 32379
# ((178, 161), 11)
# 32380
# ((178, 162), 8)
# 32381
# ((178, 163), 11)
# 32382
# ((178, 164), 11)
# 32383
# ((178, 165), 14)
# 32384
# ((178, 166), 7)
# 32385
# ((178, 167), 36)
# 32386
# ((178, 168), 20)
# 32387
# ((178, 169), 76)
# 32388
# ((178, 170), 30)
# 32389
# ((178, 171), 22)
# 32390
# ((178, 172), 19)
# 32391
# ((178, 173), 32)
# 32392
# ((178, 174), 41)
# 32393
# ((178, 175), 10)
# 32394
# ((178, 176), 30)
# 32395
# ((178, 177), 12)
# 32396
# ((178, 178), 12)
# 32397
# ((178, 179), 10)
# 32398
# ((178, 180), 12)
# 32399
# ((179, 0), 4)
# 32400
# ((179, 1), 6)
# 32401
# ((179, 2), 6)
# 32402
# ((179, 3), 6)
# 32403
# ((179, 4), 7)
# 32404
# ((179, 5), 6)
# 32405
# ((179, 6), 6)
# 32406
# ((179, 7), 7)
# 32407
# ((179, 8), 4)
# 32408
# ((179, 9), 9)
# 32409
# ((179, 10), 11)
# 32410
# ((179, 11), 8)
# 32411
# ((179, 12), 7)
# 32412
# ((179, 13), 7)
# 32413
# ((179, 14), 9)
# 32414
# ((179, 15), 11)
# 32415
# ((179, 16), 11)
# 32416
# ((179, 17), 6)
# 32417
# ((179, 18), 10)
# 32418
# ((179, 19), 14)
# 32419
# ((179, 20), 5)
# 32420
# ((179, 21), 8)
# 32421
# ((179, 22), 8)
# 32422
# ((179, 23), 10)
# 32423
# ((179, 24), 7)
# 32424
# ((179, 25), 12)
# 32425
# ((179, 26), 19)
# 32426
# ((179, 27), 76)
# 32427
# ((179, 28), 255)
# 32428
# ((179, 29), 254)
# 32429
# ((179, 30), 76)
# 32430
# ((179, 31), 76)
# 32431
# ((179, 32), 13)
# 32432
# ((179, 33), 13)
# 32433
# ((179, 34), 9)
# 32434
# ((179, 35), 17)
# 32435
# ((179, 36), 10)
# 32436
# ((179, 37), 8)
# 32437
# ((179, 38), 7)
# 32438
# ((179, 39), 4)
# 32439
# ((179, 40), 4)
# 32440
# ((179, 41), 9)
# 32441
# ((179, 42), 7)
# 32442
# ((179, 43), 6)
# 32443
# ((179, 44), 9)
# 32444
# ((179, 45), 2)
# 32445
# ((179, 46), 9)
# 32446
# ((179, 47), 4)
# 32447
# ((179, 48), 10)
# 32448
# ((179, 49), 8)
# 32449
# ((179, 50), 7)
# 32450
# ((179, 51), 7)
# 32451
# ((179, 52), 9)
# 32452
# ((179, 53), 10)
# 32453
# ((179, 54), 5)
# 32454
# ((179, 55), 13)
# 32455
# ((179, 56), 16)
# 32456
# ((179, 57), 2)
# 32457
# ((179, 58), 7)
# 32458
# ((179, 59), 20)
# 32459
# ((179, 60), 16)
# 32460
# ((179, 61), 11)
# 32461
# ((179, 62), 10)
# 32462
# ((179, 63), 7)
# 32463
# ((179, 64), 7)
# 32464
# ((179, 65), 5)
# 32465
# ((179, 66), 4)
# 32466
# ((179, 67), 8)
# 32467
# ((179, 68), 7)
# 32468
# ((179, 69), 15)
# 32469
# ((179, 70), 7)
# 32470
# ((179, 71), 8)
# 32471
# ((179, 72), 13)
# 32472
# ((179, 73), 13)
# 32473
# ((179, 74), 5)
# 32474
# ((179, 75), 4)
# 32475
# ((179, 76), 4)
# 32476
# ((179, 77), 12)
# 32477
# ((179, 78), 10)
# 32478
# ((179, 79), 11)
# 32479
# ((179, 80), 6)
# 32480
# ((179, 81), 6)
# 32481
# ((179, 82), 13)
# 32482
# ((179, 83), 12)
# 32483
# ((179, 84), 6)
# 32484
# ((179, 85), 11)
# 32485
# ((179, 86), 7)
# 32486
# ((179, 87), 9)
# 32487
# ((179, 88), 5)
# 32488
# ((179, 89), 6)
# 32489
# ((179, 90), 12)
# 32490
# ((179, 91), 15)
# 32491
# ((179, 92), 7)
# 32492
# ((179, 93), 9)
# 32493
# ((179, 94), 8)
# 32494
# ((179, 95), 12)
# 32495
# ((179, 96), 6)
# 32496
# ((179, 97), 8)
# 32497
# ((179, 98), 7)
# 32498
# ((179, 99), 13)
# 32499
# ((179, 100), 8)
# 32500
# ((179, 101), 13)
# 32501
# ((179, 102), 14)
# 32502
# ((179, 103), 19)
# 32503
# ((179, 104), 11)
# 32504
# ((179, 105), 62)
# 32505
# ((179, 106), 14)
# 32506
# ((179, 107), 10)
# 32507
# ((179, 108), 5)
# 32508
# ((179, 109), 12)
# 32509
# ((179, 110), 8)
# 32510
# ((179, 111), 8)
# 32511
# ((179, 112), 14)
# 32512
# ((179, 113), 9)
# 32513
# ((179, 114), 6)
# 32514
# ((179, 115), 11)
# 32515
# ((179, 116), 10)
# 32516
# ((179, 117), 10)
# 32517
# ((179, 118), 6)
# 32518
# ((179, 119), 7)
# 32519
# ((179, 120), 10)
# 32520
# ((179, 121), 5)
# 32521
# ((179, 122), 10)
# 32522
# ((179, 123), 7)
# 32523
# ((179, 124), 5)
# 32524
# ((179, 125), 10)
# 32525
# ((179, 126), 9)
# 32526
# ((179, 127), 5)
# 32527
# ((179, 128), 10)
# 32528
# ((179, 129), 10)
# 32529
# ((179, 130), 6)
# 32530
# ((179, 131), 12)
# 32531
# ((179, 132), 9)
# 32532
# ((179, 133), 4)
# 32533
# ((179, 134), 12)
# 32534
# ((179, 135), 7)
# 32535
# ((179, 136), 12)
# 32536
# ((179, 137), 12)
# 32537
# ((179, 138), 38)
# 32538
# ((179, 139), 13)
# 32539
# ((179, 140), 16)
# 32540
# ((179, 141), 23)
# 32541
# ((179, 142), 12)
# 32542
# ((179, 143), 13)
# 32543
# ((179, 144), 8)
# 32544
# ((179, 145), 4)
# 32545
# ((179, 146), 10)
# 32546
# ((179, 147), 3)
# 32547
# ((179, 148), 20)
# 32548
# ((179, 149), 14)
# 32549
# ((179, 150), 15)
# 32550
# ((179, 151), 21)
# 32551
# ((179, 152), 9)
# 32552
# ((179, 153), 14)
# 32553
# ((179, 154), 16)
# 32554
# ((179, 155), 8)
# 32555
# ((179, 156), 6)
# 32556
# ((179, 157), 7)
# 32557
# ((179, 158), 14)
# 32558
# ((179, 159), 4)
# 32559
# ((179, 160), 18)
# 32560
# ((179, 161), 10)
# 32561
# ((179, 162), 9)
# 32562
# ((179, 163), 18)
# 32563
# ((179, 164), 20)
# 32564
# ((179, 165), 7)
# 32565
# ((179, 166), 7)
# 32566
# ((179, 167), 5)
# 32567
# ((179, 168), 14)
# 32568
# ((179, 169), 15)
# 32569
# ((179, 170), 15)
# 32570
# ((179, 171), 76)
# 32571
# ((179, 172), 43)
# 32572
# ((179, 173), 37)
# 32573
# ((179, 174), 15)
# 32574
# ((179, 175), 72)
# 32575
# ((179, 176), 76)
# 32576
# ((179, 177), 18)
# 32577
# ((179, 178), 12)
# 32578
# ((179, 179), 16)
# 32579
# ((179, 180), 15)
# 32580
# ((180, 0), 11)
# 32581
# ((180, 1), 3)
# 32582
# ((180, 2), 7)
# 32583
# ((180, 3), 6)
# 32584
# ((180, 4), 8)
# 32585
# ((180, 5), 9)
# 32586
# ((180, 6), 11)
# 32587
# ((180, 7), 5)
# 32588
# ((180, 8), 7)
# 32589
# ((180, 9), 13)
# 32590
# ((180, 10), 9)
# 32591
# ((180, 11), 9)
# 32592
# ((180, 12), 9)
# 32593
# ((180, 13), 9)
# 32594
# ((180, 14), 7)
# 32595
# ((180, 15), 11)
# 32596
# ((180, 16), 5)
# 32597
# ((180, 17), 5)
# 32598
# ((180, 18), 6)
# 32599
# ((180, 19), 9)
# 32600
# ((180, 20), 4)
# 32601
# ((180, 21), 7)
# 32602
# ((180, 22), 4)
# 32603
# ((180, 23), 8)
# 32604
# ((180, 24), 10)
# 32605
# ((180, 25), 11)
# 32606
# ((180, 26), 27)
# 32607
# ((180, 27), 76)
# 32608
# ((180, 28), 255)
# 32609
# ((180, 29), 255)
# 32610
# ((180, 30), 255)
# 32611
# ((180, 31), 76)
# 32612
# ((180, 32), 76)
# 32613
# ((180, 33), 10)
# 32614
# ((180, 34), 10)
# 32615
# ((180, 35), 16)
# 32616
# ((180, 36), 10)
# 32617
# ((180, 37), 11)
# 32618
# ((180, 38), 16)
# 32619
# ((180, 39), 10)
# 32620
# ((180, 40), 12)
# 32621
# ((180, 41), 7)
# 32622
# ((180, 42), 10)
# 32623
# ((180, 43), 10)
# 32624
# ((180, 44), 12)
# 32625
# ((180, 45), 8)
# 32626
# ((180, 46), 6)
# 32627
# ((180, 47), 4)
# 32628
# ((180, 48), 10)
# 32629
# ((180, 49), 3)
# 32630
# ((180, 50), 7)
# 32631
# ((180, 51), 10)
# 32632
# ((180, 52), 12)
# 32633
# ((180, 53), 30)
# 32634
# ((180, 54), 16)
# 32635
# ((180, 55), 10)
# 32636
# ((180, 56), 16)
# 32637
# ((180, 57), 13)
# 32638
# ((180, 58), 15)
# 32639
# ((180, 59), 9)
# 32640
# ((180, 60), 8)
# 32641
# ((180, 61), 8)
# 32642
# ((180, 62), 7)
# 32643
# ((180, 63), 6)
# 32644
# ((180, 64), 7)
# 32645
# ((180, 65), 10)
# 32646
# ((180, 66), 4)
# 32647
# ((180, 67), 6)
# 32648
# ((180, 68), 6)
# 32649
# ((180, 69), 5)
# 32650
# ((180, 70), 7)
# 32651
# ((180, 71), 7)
# 32652
# ((180, 72), 10)
# 32653
# ((180, 73), 9)
# 32654
# ((180, 74), 6)
# 32655
# ((180, 75), 5)
# 32656
# ((180, 76), 7)
# 32657
# ((180, 77), 6)
# 32658
# ((180, 78), 9)
# 32659
# ((180, 79), 6)
# 32660
# ((180, 80), 8)
# 32661
# ((180, 81), 8)
# 32662
# ((180, 82), 6)
# 32663
# ((180, 83), 10)
# 32664
# ((180, 84), 77)
# 32665
# ((180, 85), 19)
# 32666
# ((180, 86), 14)
# 32667
# ((180, 87), 7)
# 32668
# ((180, 88), 14)
# 32669
# ((180, 89), 12)
# 32670
# ((180, 90), 7)
# 32671
# ((180, 91), 9)
# 32672
# ((180, 92), 9)
# 32673
# ((180, 93), 6)
# 32674
# ((180, 94), 13)
# 32675
# ((180, 95), 7)
# 32676
# ((180, 96), 10)
# 32677
# ((180, 97), 11)
# 32678
# ((180, 98), 10)
# 32679
# ((180, 99), 11)
# 32680
# ((180, 100), 8)
# 32681
# ((180, 101), 13)
# 32682
# ((180, 102), 13)
# 32683
# ((180, 103), 19)
# 32684
# ((180, 104), 15)
# 32685
# ((180, 105), 10)
# 32686
# ((180, 106), 15)
# 32687
# ((180, 107), 6)
# 32688
# ((180, 108), 9)
# 32689
# ((180, 109), 5)
# 32690
# ((180, 110), 6)
# 32691
# ((180, 111), 18)
# 32692
# ((180, 112), 7)
# 32693
# ((180, 113), 11)
# 32694
# ((180, 114), 7)
# 32695
# ((180, 115), 7)
# 32696
# ((180, 116), 11)
# 32697
# ((180, 117), 11)
# 32698
# ((180, 118), 6)
# 32699
# ((180, 119), 12)
# 32700
# ((180, 120), 8)
# 32701
# ((180, 121), 6)
# 32702
# ((180, 122), 5)
# 32703
# ((180, 123), 8)
# 32704
# ((180, 124), 18)
# 32705
# ((180, 125), 12)
# 32706
# ((180, 126), 9)
# 32707
# ((180, 127), 15)
# 32708
# ((180, 128), 14)
# 32709
# ((180, 129), 14)
# 32710
# ((180, 130), 7)
# 32711
# ((180, 131), 15)
# 32712
# ((180, 132), 10)
# 32713
# ((180, 133), 5)
# 32714
# ((180, 134), 9)
# 32715
# ((180, 135), 16)
# 32716
# ((180, 136), 13)
# 32717
# ((180, 137), 8)
# 32718
# ((180, 138), 1)
# 32719
# ((180, 139), 9)
# 32720
# ((180, 140), 11)
# 32721
# ((180, 141), 12)
# 32722
# ((180, 142), 7)
# 32723
# ((180, 143), 14)
# 32724
# ((180, 144), 8)
# 32725
# ((180, 145), 8)
# 32726
# ((180, 146), 13)
# 32727
# ((180, 147), 9)
# 32728
# ((180, 148), 17)
# 32729
# ((180, 149), 15)
# 32730
# ((180, 150), 11)
# 32731
# ((180, 151), 10)
# 32732
# ((180, 152), 11)
# 32733
# ((180, 153), 18)
# 32734
# ((180, 154), 11)
# 32735
# ((180, 155), 7)
# 32736
# ((180, 156), 10)
# 32737
# ((180, 157), 6)
# 32738
# ((180, 158), 14)
# 32739
# ((180, 159), 18)
# 32740
# ((180, 160), 7)
# 32741
# ((180, 161), 8)
# 32742
# ((180, 162), 12)
# 32743
# ((180, 163), 11)
# 32744
# ((180, 164), 8)
# 32745
# ((180, 165), 9)
# 32746
# ((180, 166), 14)
# 32747
# ((180, 167), 9)
# 32748
# ((180, 168), 8)
# 32749
# ((180, 169), 28)
# 32750
# ((180, 170), 24)
# 32751
# ((180, 171), 22)
# 32752
# ((180, 172), 61)
# 32753
# ((180, 173), 66)
# 32754
# ((180, 174), 15)
# 32755
# ((180, 175), 12)
# 32756
# ((180, 176), 13)
# 32757
# ((180, 177), 25)
# 32758
# ((180, 178), 17)
# 32759
# ((180, 179), 28)
# 32760
# ((180, 180), 6)

# %%
 np.ndenumerate(pic)

# %%
r = circ.radius
(x0, y0) = circ.center
print(r, x0, y0)

def calc_intensity():
    result = 0
    (Np, Nq) = pic.shape
    for p in range(Np):
        for q in range(Nq):
            # zero indexed
            value = pic[p,q]
            if ( r**2 <= (x0-p)**2 + (y0-q)**2 ):
                result += value
    return result
# Out:
# (42.0, 76, 60)

# %%
# %timeit calc_intensity()
# Out:
# 10 loops, best of 3: 67 ms per loop

# %%
??circ.contains_point

# %%
# %timeit [circ.contains_point(index) for index,value in np.ndenumerate(pic)]
# Out:
# 1 loop, best of 3: 3.09 s per loop

# %%
circy,circx,radius,qual = find_circle_coordinates(pic,0,0)
print(circy,circx)
fig, (ax,ax2) = plt.subplots(ncols=2, nrows=1, figsize=(10, 4))
im = ax.imshow(pic, cmap=plt.cm.gray)
circ = create_circle_patches((circx,circy),radius, transform=ax.transData)
ax2.add_patch(circ)
im.set_clip_path(circ)

ax2.imshow(pic,cmap=plt.cm.gray)
plt.show()
# Out:
# (101, 108)

# %%
pic.apply(circ.contains_ponum
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-560b0aa7b40e> in <module>()
# ----> 1 ax2.as_matrix()
#
# AttributeError: 'AxesSubplot' object has no attribute 'as_matrix'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-13399dae4c1b> in <module>()
# ----> 1 np.filter()
#
# AttributeError: 'module' object has no attribute 'filter'

# %%
circ = create_circle_patches((circx,circy),radius,None)

circ.contains_point((120,75))
# Out:
# False

# %%
[value for index,value in np.ndenumerate(pic[:75]) if circ.contains_point(index)]
# Out:
# [45,
#  42,
#  55,
#  64,
#  51,
#  43,
#  59,
#  47,
#  37,
#  51,
#  76,
#  51,
#  48,
#  47,
#  44,
#  41,
#  45,
#  70,
#  44,
#  39,
#  51,
#  41,
#  38,
#  38,
#  50,
#  54,
#  53,
#  26,
#  41,
#  39,
#  56,
#  40,
#  39,
#  41,
#  63,
#  37,
#  56,
#  51,
#  44,
#  59,
#  33,
#  44,
#  48,
#  65,
#  51,
#  45,
#  41,
#  43,
#  46,
#  41,
#  58,
#  50,
#  50,
#  43,
#  59,
#  48,
#  41,
#  47,
#  45,
#  40,
#  39,
#  30,
#  33,
#  41,
#  23,
#  41,
#  38,
#  39,
#  49,
#  46,
#  59,
#  56,
#  43,
#  54,
#  62,
#  39,
#  43,
#  47,
#  52,
#  46,
#  46,
#  44,
#  42,
#  65,
#  61,
#  34,
#  65,
#  47,
#  52,
#  48,
#  35,
#  64,
#  31,
#  42,
#  41,
#  36,
#  37,
#  45,
#  44,
#  51,
#  39,
#  45,
#  49,
#  37,
#  49,
#  43,
#  60,
#  42,
#  62,
#  58,
#  45,
#  45,
#  56,
#  49,
#  62,
#  44,
#  38,
#  55,
#  35,
#  51,
#  53,
#  45,
#  45,
#  42,
#  59,
#  32,
#  51,
#  44,
#  45,
#  49,
#  38,
#  41,
#  45,
#  41,
#  47,
#  44,
#  53,
#  44,
#  49,
#  49,
#  58,
#  46,
#  42,
#  49,
#  57,
#  42,
#  57,
#  37,
#  56,
#  47,
#  45,
#  48,
#  67,
#  66,
#  48,
#  42,
#  58,
#  43,
#  59,
#  49,
#  57,
#  52,
#  52,
#  47,
#  35,
#  48,
#  45,
#  43,
#  40,
#  46,
#  48,
#  45,
#  58,
#  53,
#  44,
#  46,
#  49,
#  40,
#  23,
#  28,
#  61,
#  76,
#  59,
#  34,
#  46,
#  42,
#  55,
#  41,
#  69,
#  43,
#  41,
#  49,
#  57,
#  38,
#  57,
#  38,
#  51,
#  46,
#  62,
#  41,
#  46,
#  47,
#  55,
#  49,
#  46,
#  43,
#  58,
#  45,
#  41,
#  46,
#  48,
#  46,
#  41,
#  44,
#  56,
#  47,
#  49,
#  52,
#  53,
#  49,
#  48,
#  42,
#  56,
#  38,
#  52,
#  32,
#  48,
#  31,
#  54,
#  54,
#  57,
#  39,
#  34,
#  51,
#  65,
#  36,
#  48,
#  66,
#  37,
#  51,
#  69,
#  60,
#  62,
#  40,
#  55,
#  52,
#  48,
#  61,
#  61,
#  44,
#  64,
#  32,
#  34,
#  40,
#  39,
#  55,
#  48,
#  45,
#  50,
#  35,
#  76,
#  76,
#  67,
#  51,
#  48,
#  43,
#  47,
#  44,
#  57,
#  41,
#  27,
#  28,
#  33,
#  59,
#  27,
#  36,
#  27,
#  76,
#  54,
#  50,
#  43,
#  55,
#  50,
#  47,
#  43,
#  57,
#  29,
#  36,
#  50,
#  54,
#  45,
#  61,
#  52,
#  60,
#  54,
#  57,
#  46,
#  44,
#  38,
#  42,
#  46,
#  57,
#  44,
#  47,
#  54,
#  43,
#  43,
#  46,
#  51,
#  47,
#  45,
#  48,
#  37,
#  30,
#  36,
#  45,
#  43,
#  52,
#  50,
#  67,
#  51,
#  28,
#  39,
#  63,
#  47,
#  46,
#  43,
#  47,
#  36,
#  57,
#  52,
#  45,
#  38,
#  50,
#  58,
#  42,
#  45,
#  50,
#  55,
#  54,
#  55,
#  36,
#  49,
#  42,
#  55,
#  48,
#  55,
#  48,
#  46,
#  51,
#  35,
#  38,
#  35,
#  32,
#  46,
#  38,
#  57,
#  32,
#  36,
#  30,
#  43,
#  29,
#  35,
#  50,
#  33,
#  35,
#  38,
#  29,
#  32,
#  43,
#  52,
#  41,
#  39,
#  45,
#  54,
#  49,
#  47,
#  40,
#  42,
#  34,
#  41,
#  54,
#  39,
#  42,
#  43,
#  50,
#  57,
#  47,
#  48,
#  50,
#  59,
#  65,
#  53,
#  50,
#  48,
#  47,
#  55,
#  64,
#  54,
#  51,
#  52,
#  51,
#  55,
#  30,
#  36,
#  39,
#  31,
#  33,
#  35,
#  33,
#  19,
#  30,
#  37,
#  47,
#  42,
#  44,
#  30,
#  32,
#  54,
#  39,
#  43,
#  49,
#  39,
#  39,
#  37,
#  26,
#  36,
#  30,
#  45,
#  33,
#  34,
#  42,
#  44,
#  34,
#  35,
#  42,
#  47,
#  43,
#  45,
#  44,
#  45,
#  39,
#  51,
#  42,
#  33,
#  45,
#  58,
#  65,
#  53,
#  54,
#  53,
#  60,
#  49,
#  51,
#  43,
#  32,
#  42,
#  27,
#  30,
#  42,
#  34,
#  30,
#  34,
#  40,
#  32,
#  27,
#  30,
#  33,
#  35,
#  51,
#  44,
#  42,
#  42,
#  54,
#  42,
#  36,
#  50,
#  54,
#  54,
#  46,
#  56,
#  53,
#  39,
#  76,
#  76,
#  45,
#  31,
#  43,
#  37,
#  45,
#  37,
#  57,
#  48,
#  35,
#  40,
#  51,
#  44,
#  52,
#  40,
#  47,
#  57,
#  73,
#  43,
#  48,
#  41,
#  56,
#  52,
#  41,
#  46,
#  43,
#  50,
#  41,
#  31,
#  23,
#  21,
#  39,
#  27,
#  12,
#  40,
#  23,
#  21,
#  23,
#  14,
#  19,
#  22,
#  19,
#  28,
#  32,
#  18,
#  24,
#  35,
#  42,
#  41,
#  53,
#  47,
#  40,
#  36,
#  45,
#  22,
#  49,
#  30,
#  50,
#  53,
#  49,
#  54,
#  40,
#  36,
#  40,
#  41,
#  23,
#  47,
#  39,
#  41,
#  42,
#  56,
#  37,
#  35,
#  29,
#  42,
#  49,
#  33,
#  27,
#  38,
#  76,
#  48,
#  53,
#  69,
#  68,
#  37,
#  65,
#  44,
#  55,
#  27,
#  33,
#  45,
#  26,
#  29,
#  25,
#  21,
#  16,
#  25,
#  24,
#  15,
#  30,
#  39,
#  38,
#  36,
#  42,
#  40,
#  27,
#  28,
#  34,
#  36,
#  26,
#  46,
#  34,
#  39,
#  45,
#  48,
#  41,
#  43,
#  46,
#  46,
#  34,
#  44,
#  50,
#  42,
#  56,
#  55,
#  55,
#  41,
#  67,
#  40,
#  41,
#  46,
#  60,
#  40,
#  41,
#  38,
#  51,
#  33,
#  32,
#  45,
#  54,
#  41,
#  39,
#  52,
#  55,
#  38,
#  42,
#  31,
#  51,
#  61,
#  25,
#  39,
#  31,
#  38,
#  20,
#  33,
#  19,
#  28,
#  20,
#  17,
#  38,
#  47,
#  41,
#  52,
#  63,
#  29,
#  48,
#  33,
#  30,
#  40,
#  33,
#  47,
#  32,
#  38,
#  28,
#  21,
#  49,
#  38,
#  43,
#  47,
#  44,
#  37,
#  50,
#  50,
#  59,
#  42,
#  34,
#  33,
#  50,
#  32,
#  42,
#  50,
#  14,
#  31,
#  44,
#  39,
#  46,
#  37,
#  41,
#  47,
#  40,
#  55,
#  49,
#  46,
#  39,
#  48,
#  37,
#  42,
#  32,
#  55,
#  43,
#  42,
#  46,
#  28,
#  26,
#  28,
#  29,
#  30,
#  22,
#  27,
#  28,
#  28,
#  35,
#  42,
#  22,
#  41,
#  27,
#  44,
#  43,
#  41,
#  34,
#  27,
#  45,
#  36,
#  38,
#  76,
#  43,
#  35,
#  45,
#  29,
#  26,
#  34,
#  33,
#  36,
#  28,
#  35,
#  43,
#  37,
#  41,
#  36,
#  52,
#  54,
#  44,
#  38,
#  47,
#  43,
#  46,
#  12,
#  28,
#  28,
#  33,
#  38,
#  57,
#  38,
#  35,
#  32,
#  46,
#  42,
#  35,
#  32,
#  54,
#  37,
#  57,
#  38,
#  45,
#  45,
#  55,
#  41,
#  44,
#  29,
#  20,
#  27,
#  31,
#  29,
#  16,
#  27,
#  34,
#  37,
#  51,
#  37,
#  36,
#  37,
#  42,
#  32,
#  28,
#  27,
#  36,
#  40,
#  36,
#  47,
#  42,
#  35,
#  39,
#  36,
#  34,
#  33,
#  14,
#  26,
#  44,
#  31,
#  43,
#  40,
#  47,
#  43,
#  45,
#  44,
#  36,
#  49,
#  46,
#  43,
#  50,
#  37,
#  37,
#  45,
#  10,
#  15,
#  16,
#  41,
#  33,
#  37,
#  45,
#  49,
#  39,
#  50,
#  46,
#  40,
#  52,
#  42,
#  39,
#  39,
#  44,
#  53,
#  48,
#  48,
#  48,
#  27,
#  23,
#  24,
#  41,
#  21,
#  15,
#  21,
#  24,
#  33,
#  40,
#  34,
#  40,
#  44,
#  41,
#  46,
#  45,
#  38,
#  34,
#  39,
#  49,
#  29,
#  42,
#  36,
#  37,
#  37,
#  36,
#  30,
#  44,
#  35,
#  37,
#  23,
#  28,
#  28,
#  27,
#  39,
#  46,
#  43,
#  31,
#  33,
#  41,
#  60,
#  51,
#  29,
#  43,
#  30,
#  48,
#  44,
#  38,
#  8,
#  11,
#  16,
#  16,
#  39,
#  40,
#  50,
#  44,
#  42,
#  38,
#  35,
#  53,
#  42,
#  35,
#  45,
#  43,
#  40,
#  37,
#  57,
#  70,
#  60,
#  39,
#  32,
#  25,
#  26,
#  34,
#  27,
#  18,
#  18,
#  50,
#  32,
#  31,
#  19,
#  42,
#  37,
#  38,
#  40,
#  30,
#  24,
#  29,
#  38,
#  36,
#  24,
#  25,
#  35,
#  48,
#  45,
#  29,
#  27,
#  43,
#  36,
#  28,
#  41,
#  44,
#  37,
#  40,
#  35,
#  39,
#  56,
#  39,
#  43,
#  49,
#  41,
#  49,
#  41,
#  27,
#  40,
#  37,
#  42,
#  38,
#  35,
#  3,
#  7,
#  5,
#  19,
#  33,
#  35,
#  29,
#  38,
#  42,
#  51,
#  59,
#  36,
#  48,
#  41,
#  57,
#  32,
#  56,
#  36,
#  54,
#  62,
#  36,
#  35,
#  31,
#  21,
#  27,
#  24,
#  27,
#  24,
#  42,
#  49,
#  53,
#  36,
#  31,
#  45,
#  33,
#  26,
#  28,
#  28,
#  36,
#  33,
#  35,
#  33,
#  39,
#  32,
#  40,
#  33,
#  37,
#  39,
#  45,
#  44,
#  46,
#  37,
#  43,
#  ...]

# %%
pic
# Out:
# array([[15,  6, 17, ...,  7, 19, 18],
#        [17,  7, 15, ..., 10, 10, 28],
#        [ 9, 10, 17, ..., 19, 15, 13],
#        ...,
#        [ 7, 13,  8, ..., 12, 10, 12],
#        [ 4,  6,  6, ..., 12, 16, 15],
#        [11,  3,  7, ..., 17, 28,  6]], dtype=uint8)

# %%
# Now apply the transform to the path
newpath = transform.transform_path(path)
# Now you can use this
polygon = matpatches.PathPatch(newpath)

mask = polygon.contains_points(pic) # have mpl figure out which coords are within the contour
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-7ae461f923f9> in <module>()
#       8 polygon = matpatches.PathPatch(newpath)
#       9
# ---> 10 mask = polygon.contains_points(pic) # have mpl figure out which coords are within the contour
#
# AttributeError: 'PathPatch' object has no attribute 'contains_points'

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10, 4))
ax.add_patch(circ)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-6859cac18a81> in <module>()
#       1 fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10, 4))
# ----> 2 ax.add_patch(circ)
#       3 plt.show()
#
# /home/janekg89/Envs/flutype_webapp/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in add_patch(self, p)
#    1829         """
#    1830
# -> 1831         self._set_artist_props(p)
#    1832         if p.get_clip_path() is None:
#    1833             p.set_clip_path(self.patch)
#
# /home/janekg89/Envs/flutype_webapp/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _set_artist_props(self, a)
#     910     def _set_artist_props(self, a):
#     911         """set the boilerplate props for artists added to axes"""
# --> 912         a.set_figure(self.figure)
#     913         if not a.is_transform_set():
#     914             a.set_transform(self.transData)
#
# /home/janekg89/Envs/flutype_webapp/local/lib/python2.7/site-packages/matplotlib/artist.pyc in set_figure(self, fig)
#     610         # to more than one Axes
#     611         if self.figure is not None:
# --> 612             raise RuntimeError("Can not put single artist in "
#     613                                "more than one figure")
#     614         self.figure = fig
#
# RuntimeError: Can not put single artist in more than one figure
