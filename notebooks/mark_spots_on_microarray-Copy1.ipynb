# %%
STUDY = "2018-01-24_microarray"
MEASUREMENTS = ["180124_N21_Pan", "180124_E14_X31", "180124_N22_Cal", "180124_N23_X31", "180124_E15_X31"]
DIRECTORY = ["{}/{}".format(STUDY,measurement) for measurement in MEASUREMENTS]
IMAGE_PATHS = ["180124_N21_Pan.gif",
                '180124_E14_X31_Allantois_100_600_635_635_2_635.gif',
                '180124_N22_Cal_100_600_635_635_635.gif',
                '180124_N23_X31_100_600_635_635_635_635.gif',
                '180124_E15_X31_100_600_635_635.gif',
               ]

IMAGE_PATHS_JPG  = [im_path.replace('.gif', '.jpg') for im_path in IMAGE_PATHS]
FPATH_DICT = dict(zip(DIRECTORY, IMAGE_PATHS_JPG))
FPATH_DICT = {key: 'data/' + key + '/' + value for key, value in FPATH_DICT.items()}
#BLOCK_SHAPE = Point(10,10)
COLLECTIONS = {}
PEP_PATH = "base_pep.gal"

# %%
pprint(FPATH_DICT)
# Out:
# Pretty printing has been turned OFF

# %%
import os
import repackage
from pprint import pprint
from importlib import reload
repackage.up()
from spot2intensity.data import COLLECTIONS
reload(spot2intensity.data)
from spot2intensity.spot2intensity import Spots
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-80d619a74e97> in <module>()
#       4 from importlib import reload
#       5 repackage.up()
# ----> 6 from spot2intensity.data import COLLECTIONS
#       7 reload(spot2intensity.data)
#       8 from spot2intensity.spot2intensity import Spots
#
# ~/Dev/flutype_analysis_web/spot2intensity/data.py in <module>()
#      47 COLLECTIONS["180124_E14_X31"]= Collection(grids=grids,
#      48                                           name="180124_E14_X31",
# ---> 49                                           jpg_path=FPATH_DICT["180124_E14_X31"],
#      50                                           study=STUDY,
#      51                                           pep_path=PEP_PATH,)
#
# KeyError: '180124_E14_X31'

# %%
COLLECTIONS = load_data()

# %%
COLLECTIONS["slide_24"].dump_pickel()
# Out:
# <slide_24> is beeing pickeled
# ...
# Claculating grid starting at:(43,144)
# /home/janek89/Envs/flutype_webapp/lib/python3.5/site-packages/scipy/ndimage/measurements.py:431: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   safe = ((np.issubdtype(dt, int) and dt.itemsize <= int_size) or

# %%
spots = Spots.load_pickel(COLLECTIONS["slide_24"])

# %%
spots.plot_grid(figsize=(20,40))
plt.show()

# %%
spots.df = spots.df[spots.df["Name"] == "Nenad"]
display(spots.df)
spots.df = spots.df[spots.df["circle_qual"] > 0.5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Envs/flutype_webapp/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     334             method = get_real_method(obj, self.print_method)
#     335             if method is not None:
# --> 336                 return method()
#     337             return None
#     338         else:
#
# ~/Envs/flutype_webapp/lib/python3.5/site-packages/pandas/core/frame.py in _repr_html_(self)
#     667
#     668             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 669                                 show_dimensions=show_dimensions, notebook=True)
#     670         else:
#     671             return None
#
# ...

# %%
spots.plot_grid(figsize = (30,30))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-6e95d3940bc1> in <module>()
#       1
# ----> 2 spots.plot_grid(figsize = (30,30))
#       3 plt.show()
#
# ~/Dev/flutype_analysis_web/spot2intensity/spot2intensity.py in plot_grid(self, on, **kwargs)
#      45         for i, spot in self.df.iterrows():
#      46             circ = create_circle_patches(spot["circles"].center, spot["circles"].radius)
# ---> 47             rec = patches.Rectangle((spot["squares"].get_xy()),
#      48                                     spot["squares"].get_width(),
#      49                                     spot["squares"].get_height(),
#
# ~/Envs/flutype_webapp/lib/python3.5/site-packages/matplotlib/patches.py in get_xy(self)
#     703     def get_xy(self):
#     704         "Return the left and bottom coords of the rectangle"
# --> 705         return self._x, self._y
#     706
# ...
