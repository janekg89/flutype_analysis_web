# %%
from __future__ import absolute_import, print_function, unicode_literals
import sys
import os
import repackage
repackage.up()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from importlib import reload
import analysis2 as a2
reload(a2)
from IPython.display import display, HTML
from flutype.models import Spot
import preprocessing as pre
#from preprocessing import mean_on_analyte_batch, 
import seaborn as sns
from itertools import combinations
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.cm as cm
import preprocessing as pre
# Out:
# ****************************************
# RUNNING IN DEVELOP
# ****************************************
# /home/janekg89/Envs/flutype_webapp3/lib/python3.5/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# /home/janekg89/Envs/flutype_webapp3/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
reload(pre)
reload(a2)
# Out:
# <module 'analysis2' from '/home/janekg89/Develop/Pycharm_Projects/flutype_analysis_web/analysis2.py'>

# %%
studies = ["microarray_2018_03_21"]
spots_dj = Spot.objects.filter(raw_spot__raw_spot_collection__studies__sid__in=studies)
spots_before = spots_dj.filter(spot_collection__sid = "before")
spots_quant = spots_dj.filter(spot_collection__sid = "quant1")

#spots_dj = spots_dj.filter(raw_spot__lig_mob_batch__sid = "A/Perth/16/2009(H3N2)-2018-04-13")

#spots_dj = spots_dj.filter(circle_quality__gte = 0.3)
cs = ["2018_03_21_slide_31","2018_03_21_slide_69"]
spots_dj =  spots_quant.exclude(raw_spot__raw_spot_collection__sid__in=cs)
data = a2.Data(spots_dj=spots_dj).outlier_filtering()

# %%
#spots_dj = Spot.objects.filter(raw_spot__raw_spot_collection__studies__sid__in=studies)
#spots_dj = spots_dj.exclude(spot_collection__sid = "raw")

# %%
#data = a2.Data(spots_dj=spots_dj)

# %%
#pre.mean_on_(data.spots_pd).groupby("Collection").mean()
mean_collection = pre.mean_on_collection(data.spots_pd)

# %%
mean_on_ana = pre.mean_on_analyte_batch(data.spots_pd)

# %%
ma = mean_on_ana.groupby(["Analyte Batch"]).mean()["Intensity_rsd"]

# %%
mc = mean_collection.groupby(["Analyte Batch"]).mean()["Intensity_rsd"]

# %%
#mc = mean_collection.groupby(["Ligand Batch"]).mean().sort_values(by="Intensity")

# %%
mc
# Out:
# Analyte Batch
# A/Aichi/2/68(H3N2)-X31-2018-04-13              0.325335
# A/Beijing/32/1992(H3N2)-2018-04-13             0.486180
# A/Brisbaine/59/2007(H1N1)-2018-04-13           0.398306
# A/Brisbane/10/2007(H3N2)-2018-04-13            0.502553
# A/California/7/2009(H1N1)-2018-04-13           0.451793
# A/Hong Kong/4801/2014(H3N2)-2018-04-13         0.417490
# A/Panama/2007/1999(H3N2)-2018-04-13            0.461604
# A/Perth/16/2009(H3N2)-2018-04-13               0.439414
# A/Switzerland/9715293/2013(H3N2)-2018-04-13    0.414675
# A/Texas/50/2012(H3N2)-2018-04-13               0.440590
# A/Victoria/361/2011(H3N2)-2018-04-13           0.372573
# Mi45-2018-04-13                                0.394044
# VicAlla-2018-04-13                             0.363370
# Name: Intensity_rsd, dtype: float64

# %%
ma
# Out:
# Analyte Batch
# A/Aichi/2/68(H3N2)-X31-2018-04-13              0.467652
# A/Beijing/32/1992(H3N2)-2018-04-13             0.645617
# A/Brisbaine/59/2007(H1N1)-2018-04-13           0.497198
# A/Brisbane/10/2007(H3N2)-2018-04-13            0.640348
# A/California/7/2009(H1N1)-2018-04-13           0.589968
# A/Hong Kong/4801/2014(H3N2)-2018-04-13         0.557664
# A/Panama/2007/1999(H3N2)-2018-04-13            0.621664
# A/Perth/16/2009(H3N2)-2018-04-13               0.555167
# A/Switzerland/9715293/2013(H3N2)-2018-04-13    0.490421
# A/Texas/50/2012(H3N2)-2018-04-13               0.559173
# A/Victoria/361/2011(H3N2)-2018-04-13           0.636376
# Mi45-2018-04-13                                0.491717
# VicAlla-2018-04-13                             0.432381
# Name: Intensity_rsd, dtype: float64

# %%
#plt.scatter(mc["Intensity"],mc["Intensity_rsd"])
#plt.show()

# %%
1-mc/ma
# Out:
# Analyte Batch
# A/Aichi/2/68(H3N2)-X31-2018-04-13              0.304322
# A/Beijing/32/1992(H3N2)-2018-04-13             0.246954
# A/Brisbaine/59/2007(H1N1)-2018-04-13           0.198900
# A/Brisbane/10/2007(H3N2)-2018-04-13            0.215188
# A/California/7/2009(H1N1)-2018-04-13           0.234208
# A/Hong Kong/4801/2014(H3N2)-2018-04-13         0.251360
# A/Panama/2007/1999(H3N2)-2018-04-13            0.257471
# A/Perth/16/2009(H3N2)-2018-04-13               0.208501
# A/Switzerland/9715293/2013(H3N2)-2018-04-13    0.154452
# A/Texas/50/2012(H3N2)-2018-04-13               0.212069
# A/Victoria/361/2011(H3N2)-2018-04-13           0.414540
# Mi45-2018-04-13                                0.198635
# VicAlla-2018-04-13                             0.159608
# Name: Intensity_rsd, dtype: float64

# %%
d = data
d = d.subset_ligand_batches(["Nenad"])
fig ,ax = plt.subplots(figsize=(10,50))

ax = sns.violinplot(y="Analyte Batch",
                    x="Intensity",
                    bw=.2, 
                    #hue="Collection",
                    scale="width", 
                    data=d.spots_pd.sort_values(by="Analyte Batch"),
                    #split=True,
                    color="white",

                    )
ax = sns.swarmplot(y="Analyte Batch",
                   hue="Collection", 
                   x="Intensity",
                   palette=sns.color_palette("inferno",n_colors=3),
                   #color="white",
                   data=d.spots_pd.sort_values(by="Analyte Batch"),
                   size=8,
                   #split=True,
                   edgecolor="grey",
                   linewidth=0.1,)
        
ax.legend_.remove()
plt.show()

# %%
d.spots_pd
# Out:
#       Ligand Batch  Ligand Batch Concentration Ligand  \
# 10341         P098                         1.0   P098
# 10434         P098                         1.0   P098
# 10466         P098                         1.0   P098
# 10559         P098                         1.0   P098
# 10652         P098                         1.0   P098
# 10811         P098                         1.0   P098
# 10904         P098                         1.0   P098
# 11058         P098                         1.0   P098
# 11085         P098                         1.0   P098
# 11201         P098                         1.0   P098
# 11294         P098                         1.0   P098
# 11413         P098                         1.0   P098
# 11506         P098                         1.0   P098
# 11555         P098                         1.0   P098
# 11648         P098                         1.0   P098
# 11785         P098                         1.0   P098
# 11878         P098                         1.0   P098
# 11940         P098                         1.0   P098
# 2652          P098                         1.0   P098
# 2745          P098                         1.0   P098
# 2842          P098                         1.0   P098
# 2974          P098                         1.0   P098
# 3022          P098                         1.0   P098
# 3115          P098                         1.0   P098
# 3253          P098                         1.0   P098
# 3346          P098                         1.0   P098
# 3390          P098                         1.0   P098
# 6921          P098                         1.0   P098
# 7088          P098                         1.0   P098
# 7181          P098                         1.0   P098
# ...            ...                         ...    ...
# 13184         P098                         1.0   P098
# 13277         P098                         1.0   P098
# 13417         P098                         1.0   P098
# 13510         P098                         1.0   P098
# 13633         P098                         1.0   P098
# 13650         P098                         1.0   P098
# 18891         P098                         1.0   P098
# 19009         P098                         1.0   P098
# 19102         P098                         1.0   P098
# 19192         P098                         1.0   P098
# 19283         P098                         1.0   P098
# 19353         P098                         1.0   P098
# 19446         P098                         1.0   P098
# 19562         P098                         1.0   P098
# 19635         P098                         1.0   P098
# 18036         P098                         1.0   P098
# 18160         P098                         1.0   P098
# 18253         P098                         1.0   P098
# 18374         P098                         1.0   P098
# 18468         P098                         1.0   P098
# 18529         P098                         1.0   P098
# 18622         P098                         1.0   P098
# 18747         P098                         1.0   P098
# 16331         P098                         1.0   P098
# 16571         P098                         1.0   P098
# 16680         P098                         1.0   P098
# 16773         P098                         1.0   P098
# 16845         P098                         1.0   P098
# 16938         P098                         1.0   P098
# 17052         P098                         1.0   P098
#
#                                 Analyte Batch                      Analyte  \
# 10341        A/Perth/16/2009(H3N2)-2018-04-13        A/Perth/16/2009(H3N2)
# 10434        A/Perth/16/2009(H3N2)-2018-04-13        A/Perth/16/2009(H3N2)
# 10466        A/Perth/16/2009(H3N2)-2018-04-13        A/Perth/16/2009(H3N2)
# 10559        A/Perth/16/2009(H3N2)-2018-04-13        A/Perth/16/2009(H3N2)
# 10652        A/Perth/16/2009(H3N2)-2018-04-13        A/Perth/16/2009(H3N2)
# 10811        A/Perth/16/2009(H3N2)-2018-04-13        A/Perth/16/2009(H3N2)
# 10904        A/Perth/16/2009(H3N2)-2018-04-13        A/Perth/16/2009(H3N2)
# 11058        A/Perth/16/2009(H3N2)-2018-04-13        A/Perth/16/2009(H3N2)
# 11085        A/Perth/16/2009(H3N2)-2018-04-13        A/Perth/16/2009(H3N2)
# 11201        A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 11294        A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 11413        A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 11506        A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 11555        A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 11648        A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 11785        A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 11878        A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 11940        A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 2652         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 2745         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 2842         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 2974         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 3022         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 3115         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 3253         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 3346         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 3390         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 6921         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 7088         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# 7181         A/Texas/50/2012(H3N2)-2018-04-13        A/Texas/50/2012(H3N2)
# ...                                       ...                          ...
# 13184    A/Victoria/361/2011(H3N2)-2018-04-13    A/Victoria/361/2011(H3N2)
# 13277    A/Victoria/361/2011(H3N2)-2018-04-13    A/Victoria/361/2011(H3N2)
# 13417    A/Victoria/361/2011(H3N2)-2018-04-13    A/Victoria/361/2011(H3N2)
# 13510    A/Victoria/361/2011(H3N2)-2018-04-13    A/Victoria/361/2011(H3N2)
# 13633    A/Victoria/361/2011(H3N2)-2018-04-13    A/Victoria/361/2011(H3N2)
# 13650    A/Victoria/361/2011(H3N2)-2018-04-13    A/Victoria/361/2011(H3N2)
# 18891  A/Hong Kong/4801/2014(H3N2)-2018-04-13  A/Hong Kong/4801/2014(H3N2)
# 19009  A/Hong Kong/4801/2014(H3N2)-2018-04-13  A/Hong Kong/4801/2014(H3N2)
# 19102  A/Hong Kong/4801/2014(H3N2)-2018-04-13  A/Hong Kong/4801/2014(H3N2)
# 19192  A/Hong Kong/4801/2014(H3N2)-2018-04-13  A/Hong Kong/4801/2014(H3N2)
# 19283  A/Hong Kong/4801/2014(H3N2)-2018-04-13  A/Hong Kong/4801/2014(H3N2)
# 19353  A/Hong Kong/4801/2014(H3N2)-2018-04-13  A/Hong Kong/4801/2014(H3N2)
# 19446  A/Hong Kong/4801/2014(H3N2)-2018-04-13  A/Hong Kong/4801/2014(H3N2)
# 19562  A/Hong Kong/4801/2014(H3N2)-2018-04-13  A/Hong Kong/4801/2014(H3N2)
# 19635  A/Hong Kong/4801/2014(H3N2)-2018-04-13  A/Hong Kong/4801/2014(H3N2)
# 18036                      VicAlla-2018-04-13                      VicAlla
# 18160                      VicAlla-2018-04-13                      VicAlla
# 18253                      VicAlla-2018-04-13                      VicAlla
# 18374                      VicAlla-2018-04-13                      VicAlla
# 18468                      VicAlla-2018-04-13                      VicAlla
# 18529                      VicAlla-2018-04-13                      VicAlla
# 18622                      VicAlla-2018-04-13                      VicAlla
# 18747                      VicAlla-2018-04-13                      VicAlla
# 16331                      VicAlla-2018-04-13                      VicAlla
# 16571                      VicAlla-2018-04-13                      VicAlla
# 16680                      VicAlla-2018-04-13                      VicAlla
# 16773                      VicAlla-2018-04-13                      VicAlla
# 16845                      VicAlla-2018-04-13                      VicAlla
# 16938                      VicAlla-2018-04-13                      VicAlla
# 17052                      VicAlla-2018-04-13                      VicAlla
# 13184  microarray_2018_03_21  33.0    15.0          quant1      3.0
# 13277  microarray_2018_03_21  27.0    12.0          quant1      4.0
# 13417  microarray_2018_03_21  15.0     6.0          quant1      5.0
# 13510  microarray_2018_03_21   9.0     3.0          quant1      6.0
# 13633  microarray_2018_03_21  21.0     9.0          quant1      7.0
# 13650  microarray_2018_03_21   2.0    15.0          quant1      8.0
# 18891  microarray_2018_03_21  52.0     9.0          quant1      0.0
# 19009  microarray_2018_03_21  40.0     3.0          quant1      1.0
# 19102  microarray_2018_03_21  33.0    15.0          quant1      2.0
# 19192  microarray_2018_03_21  21.0     9.0          quant1      3.0
# 19283  microarray_2018_03_21  46.0     6.0          quant1      4.0
# 19353  microarray_2018_03_21  15.0     6.0          quant1      5.0
# 19446  microarray_2018_03_21   9.0     3.0          quant1      6.0
# 19562  microarray_2018_03_21  27.0    12.0          quant1      7.0
# 19635  microarray_2018_03_21   2.0    15.0          quant1      8.0
# 18036  microarray_2018_03_21  52.0     9.0          quant1      0.0
# 18160  microarray_2018_03_21  40.0     3.0          quant1      1.0
# 18253  microarray_2018_03_21  33.0    15.0          quant1      2.0
# 18374  microarray_2018_03_21  21.0     9.0          quant1      3.0
# 18468  microarray_2018_03_21  46.0     6.0          quant1      4.0
# 18529  microarray_2018_03_21  15.0     6.0          quant1      5.0
# 18622  microarray_2018_03_21   9.0     3.0          quant1      6.0
# 18747  microarray_2018_03_21  27.0    12.0          quant1      7.0
# 16331  microarray_2018_03_21  40.0     3.0          quant1      0.0
# 16571  microarray_2018_03_21  21.0     9.0          quant1      2.0
# 16680  microarray_2018_03_21  52.0     9.0          quant1      3.0
# 16773  microarray_2018_03_21  46.0     6.0          quant1      4.0
# 16845  microarray_2018_03_21  15.0     6.0          quant1      5.0
# 16938  microarray_2018_03_21   9.0     3.0          quant1      6.0
# 17052  microarray_2018_03_21  27.0    12.0          quant1      7.0
#
# [319 rows x 14 columns]

# %%
d = a2.Data(spots_pd=data.spots_pd[data.spots_pd["Collection Type"]=="quant1"])
fig ,ax = plt.subplots(figsize=(10,50))

ax = sns.violinplot(y="Collection",
                    x="Intensity",
                    bw=.2, 
                    hue="Ligand Batch",
                    scale="width", 
                    data=d.spots_pd.sort_values(by="Ligand Batch"),
                    split=True,)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-777f9e066e4a> in <module>()
#       8                     scale="width",
#       9                     data=d.spots_pd.sort_values(by="Ligand Batch"),
# ---> 10                     split=True,)
#
# ~/Envs/flutype_webapp3/lib/python3.5/site-packages/seaborn/categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2362                              bw, cut, scale, scale_hue, gridsize,
#    2363                              width, inner, split, dodge, orient, linewidth,
# -> 2364                              color, palette, saturation)
#    2365
#    2366     if ax is None:
#
# ~/Envs/flutype_webapp3/lib/python3.5/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     574         if split and self.hue_names is not None and len(self.hue_names) != 2:
#     575             msg = "There must be exactly two hue levels to use `split`.'"
# --> 576             raise ValueError(msg)
#     577         self.split = split
#     578
#
# ValueError: There must be exactly two hue levels to use `split`.'

# %%
from mpl_toolkits import mplot3d

ax = plt.axes(projection='3d')
ax.scatter(xs=data.spots_pd["Row"],ys=data.spots_pd["Column"],zs =data.spots_pd["Intensity"])
#data.spots_pd.scatter(x="Row",y="Column",z ="Intensity")
plt.show()

# %%
import numpy as np
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot
print (__version__) # requires version >= 1.9.0

#Always run this the command before at the start of notebook
init_notebook_mode(connected=True)
import plotly.graph_objs as go
from sklearn import preprocessing
# Out:
# 2.5.1
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#d = a2.Data(spots_pd=data.spots_pd.dropna())
#d = data.subset_ligand(["LF"])
d = d.subset_ligand_batches(["Nenad"])
le = preprocessing.LabelEncoder()
le.fit(d.spots_pd["Ligand Batch"])
cs = le.transform(d.spots_pd["Ligand Batch"])
colors =cs.astype(float) / cs.max()


def trace(d):
    return [go.Scatter3d(
    x=d.spots_pd["Row"],
    y=d.spots_pd["Column"],
    z=d.spots_pd["Intensity"],

    mode='lines+markers',
    marker=dict(
        size=7,
        color=colors,                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=1.1
    )
)]


layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=trace(d.subset_collection(["2018_03_21_slide_44"])), layout=layout)
iplot(fig, filename='3d-scatter-colorscale')
# Out:
# /home/janekg89/Envs/flutype_webapp3/lib/python3.5/site-packages/ipykernel_launcher.py:7: RuntimeWarning:
#
# invalid value encountered in true_divide
# <div id="c2059067-c370-4a4a-8f36-1d3b23ac693b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c2059067-c370-4a4a-8f36-1d3b23ac693b", [{"marker": {"color": [null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "size": 7, "colorscale": "Viridis", "opacity": 1.1}, "type": "scatter3d", "x": [53.0, 47.0, 35.0, 28.0, 41.0, 16.0, 10.0, 4.0, 22.0], "z": [11569.6868186323, 11726.0190930788, 27327.6809492419, 21895.6666666667, 17834.8969276511, 19504.1555996036, 9548.08126858276, 8270.07319013524, 8392.48677248677], "y": [10.0, 7.0, 1.0, 13.0, 4.0, 7.0, 4.0, 1.0, 10.0], "mode": "lines+markers"}], {"margin": {"t": 0, "b": 0, "l": 0, "r": 0}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

# %%
z = d.subset_ligand_batches(["Nenad"]).spots_pd.pivot_table(columns="Column",index="Row",values="Intensity").as_matrix()

# %%
z
# Out:
# array([[14281.2703987 ,            nan,            nan,            nan,
#                    nan],
#        [           nan, 13853.34989984,            nan,            nan,
#                    nan],
#        [           nan,            nan, 35691.86545491,            nan,
#                    nan],
#        [           nan,            nan,            nan, 43047.27396485,
#                    nan],
#        [           nan,            nan,            nan,            nan,
#         38832.97395856],
#        [34744.17537085,            nan,            nan,            nan,
#                    nan],
#        [           nan, 24874.95513362,            nan,            nan,
#                    nan],
#        [           nan,            nan, 21458.56205507,            nan,
#                    nan],
#        [           nan,            nan,            nan, 19717.62582499,
#                    nan]])

# %%
data = [
    go.Surface(
        z=z
    )
]
layout = go.Layout(
    title='Mt Bruno Elevation',
    autosize=False,
    width=500,
    height=500,
    margin=dict(
        l=65,
        r=50,
        b=65,
        t=90
    )
)
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='elevations-3d-surface')
# Out:
# <div id="28703750-b828-44ff-8acb-81b854a58510" style="height: 500px; width: 500px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("28703750-b828-44ff-8acb-81b854a58510", [{"z": [[14281.270398701028, null, null, null, null], [null, 13853.349899841072, null, null, null], [null, null, 35691.86545490962, null, null], [null, null, null, 43047.273964850465, null], [null, null, null, null, 38832.973958556395], [34744.17537084682, null, null, null, null], [null, 24874.95513362183, null, null, null], [null, null, 21458.562055069047, null, null], [null, null, null, 19717.625824988354, null]], "type": "surface"}], {"height": 500, "autosize": false, "title": "Mt Bruno Elevation", "margin": {"l": 65, "b": 65, "r": 50, "t": 90}, "width": 500}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
