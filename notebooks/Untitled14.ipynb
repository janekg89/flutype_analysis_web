# %%
import os
import repackage
repackage.up()
import data.microarray_2018_03_21.data as d1
from importlib import reload
from utils import ensure_dir
import spot2intensity.spot2intensity as sp2
import numpy as np
from PIL import Image

# %%
reload(d1)
# Out:
# <module 'data.microarray_2018_03_21.data' from '/home/janekg89/Develop/Pycharm_Projects/flutype_analysis_web/data/microarray_2018_03_21/data.py'>

# %%
COLLECTIONS = d1.load_data()

# %%
reload(sp2)
# Out:
# <module 'spot2intensity.spot2intensity' from '/home/janekg89/Develop/Pycharm_Projects/flutype_analysis_web/spot2intensity/spot2intensity.py'>

# %%
COLLECTIONS.items
# Out:
# <function dict.items>

# %%
for n,c in COLLECTIONS.items():
    old = c.tifs_a[-1].size
    im_array = np.asarray(c.tifs_b[-1])
    im_array = im_array * (255.0 / im_array.max())
    im_array = im_array.astype(np.uint8)
    im = Image.fromarray(im_array)
    im_thumb = im.thumbnail(old, Image.ANTIALIAS)
    output = os.path.join(c.base_path,c.name,"tif_b_thumb.tif")
    im.save(output)

# %%
# Out:
#      Unnamed: 0  Block  Row  Column       Name
# ID
# 1             0      1    1       1    LF-0.05
# 2             1      1    1       2    LF-0.05
# 3             2      1    1       3    LF-0.05
# 4             3      1    1       4    LF-0.05
# 5             4      1    1       5    LF-0.05
# 6             5      1    1       6    LF-0.05
# 7             6      1    1       7    LF-0.05
# 8             7      1    1       8    LF-0.05
# 9             8      1    1       9    LF-0.05
# 10            9      1    1      10    LF-0.05
# 11           10      1    1      11        NaN
# 12           11      1    1      12        NaN
# 13           12      1    1      13        NaN
# 14           13      1    1      14        NaN
# 15           14      1    1      15        NaN
# 16           15      1    2       1       P080
# 17           16      1    2       2       P081
# 18           17      1    2       3       P082
# 19           18      1    2       4       P083
# ...
