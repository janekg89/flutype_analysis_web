# %%
import os
import repackage
repackage.up()
import data.microarray_2018_02_18.data as d1
from importlib import reload
from utils import ensure_dir
import spot2intensity.spot2intensity as sp2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
reload(d1)
# Out:
# <module 'data.microarray_2018_02_18.data' from '/home/janekg89/Develop/Pycharm_Projects/flutype_analysis_web/data/microarray_2018_02_18/data.py'>

# %%
COLLECTIONS = d1.load_data()

# %%
reload(sp2)
# Out:
# <module 'spot2intensity.spot2intensity' from '/home/janekg89/Develop/Pycharm_Projects/flutype_analysis_web/spot2intensity/spot2intensity.py'>

# %%
im_array = np.asarray(COLLECTIONS['slide_30'].tifs_a[-1])
plt.figure(figsize=(20,40))
plt.imshow(im_array, cmap="gray")
plt.show()

# %%
for n,c in COLLECTIONS.items():
    old = c.tifs_a[-1].size
    im_array = np.asarray(c.tifs_b[-1])
    im_array = im_array * (255.0 / im_array.max())
    im_array = im_array.astype(np.uint8)
    im = Image.fromarray(im_array)
    im_thumb = im.thumbnail(old, Image.ANTIALIAS)
    output = os.path.join(c.base_path,c.name,"tif_b_thumb.tif")
    im.save(output)

# %%
# Out:
#      Unnamed: 0  Block  Row  Column       Name
# ID
# 1             0      1    1       1    LF-0.05
# 2             1      1    1       2    LF-0.05
# 3             2      1    1       3    LF-0.05
# 4             3      1    1       4    LF-0.05
# 5             4      1    1       5    LF-0.05
# 6             5      1    1       6    LF-0.05
# 7             6      1    1       7    LF-0.05
# 8             7      1    1       8    LF-0.05
# 9             8      1    1       9    LF-0.05
# 10            9      1    1      10    LF-0.05
# 11           10      1    1      11        NaN
# 12           11      1    1      12        NaN
# 13           12      1    1      13        NaN
# 14           13      1    1      14        NaN
# 15           14      1    1      15        NaN
# 16           15      1    2       1       P080
# 17           16      1    2       2       P081
# 18           17      1    2       3       P082
# 19           18      1    2       4       P083
# 20           19      1    2       5       P084
# 21           20      1    2       6       P086
# 22           21      1    2       7       P088
# 23           22      1    2       8       P089
# 24           23      1    2       9       P090
# 25           24      1    2      10     LF-0.1
# 26           25      1    2      11       P091
# 27           26      1    2      12       P094
# 28           27      1    2      13       P095
# 29           28      1    2      14       P096
# 30           29      1    2      15       P098
# ..          ...    ...  ...     ...        ...
# 826         825      1   56       1     P131.1
# 827         826      1   56       2       P132
# 828         827      1   56       3       P133
# 829         828      1   56       4       P116
# 830         829      1   56       5       P134
# 831         830      1   56       6       P117
# 832         831      1   56       7       P118
# 833         832      1   56       8       P119
# 834         833      1   56       9       P128
# 835         834      1   56      10       P135
# 836         835      1   56      11     LF-0.1
# 837         836      1   56      12       P120
# 838         837      1   56      13       P121
# 839         838      1   56      14       P122
# 840         839      1   56      15       P123
# 841         840      1   57       1       P124
# 842         841      1   57       2       P125
# 843         842      1   57       3       P130
# 844         843      1   57       4       P127
# 845         844      1   57       5    LF-0.05
# 846         845      1   57       6    LF-0.01
# 847         846      1   57       7   LF-0.001
# 848         847      1   57       8  LF-0.0001
# 849         848      1   57       9     LF-0.5
# 850         849      1   57      10        NaN
# 851         850      1   57      11        NaN
# 852         851      1   57      12        NaN
# 853         852      1   57      13    LF-0.05
# 854         853      1   57      14    LF-0.05
# 855         854      1   57      15        NaN
#
# [855 rows x 5 columns]
