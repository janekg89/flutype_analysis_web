# %%
import os
import repackage
repackage.up()
import data.microarray_2018_02_18.data as d1
import spot2intensity.spot2intensity as sp

# %%
Cols = d1.load_data()

# %%
c1 = sp.Spots.load_pickel(Cols["slide_31"])

# %%
c1.df.pivot_table(values="intensities2", index = "Row", columns="Column")
# Out:
# Column            1             2             3             4             5   \
# Row
# 1        1631.061947   4686.495575    181.539823    319.057716    237.612296
# 2       27431.772898   2309.750314    227.318584  20595.848365  10175.622334
# 3        4823.610619    345.098214    744.769912  31050.600595  25256.063429
# 4       52565.470728   2394.180380   2798.213152   1712.006364   3419.968178
# 5        3635.743363   5638.637390    336.911672    552.086460    118.314082
# 6         962.140733    194.796677   5736.034688    150.690265    170.725664
# 7         945.539823    159.481804    131.065665    231.044248    267.307884
# 8        1061.646018    139.221239    126.333861    157.061947   1556.954831
# 9       53673.736041  20409.696361  30150.139742   2771.001592   6795.112063
# 10       1444.815661    828.220228    256.500791  38407.204163   2795.362832
# 11       3885.206842    403.015228   1861.659306    366.078864   1881.955752
# ...

# %%
c1.plot_grid(figsize=(15,30))
